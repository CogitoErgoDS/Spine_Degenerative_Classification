# %% [markdown]
# Packages:

# %%
import glob
import os
import warnings
 
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import pydicom
from pydicom.data import get_testdata_files
from sklearn.model_selection import train_test_split

from IPython.display import Markdown, display

 # Import functions from the module
import importlib
import help_files._0_definitions 
import  help_files._1_visuals_script
# import  help_files._01_load_data
 # Reload the module to apply the changes to the script
importlib.reload(help_files._0_definitions)
importlib.reload(help_files._1_visuals_script)
# importlib.reload(help_files._01_load_data)
import  help_files._1_visuals_script  as pauls_vs
# Group by 'condition', 'level', and 'severity' and count occurrences
from help_files._0_definitions import count_severity_by_condition_level 
# Define the path
from pathlib import Path

pd.set_option("display.width", 1000)  # Set a large width to prevent line wrapping

# %%
### In definitions are all the functions that are used in the notebook and globals
with open("help_files/_0_definitions.py") as file:
    exec(file.read())

# %%
 

# Specify the file names and DataFrame variable names
file_names = ["test_df_3_cat.csv"]

# Load the data from the CSV files
dataframes = [pd.read_csv(data_path_vor / file_name) for file_name in file_names]
# Load train_df as a DataFrame
test_df = dataframes[0]
test_df = test_df.sample(frac=0.5, random_state=RSEED)
print("DataFrames have been loaded successfully.")

# %% [markdown]
# Restore parameters and metrtics from mlflow

# %% [markdown]
# I should take prdicted probabilities and not predicted classes: output scores (logits) are converted into probabilities using the softmax function

# %%
import mlflow
import mlflow.pytorch
import torch
from torch import nn, optim
from torch.utils.data import Dataset, DataLoader, random_split
import torchvision.models as models
from torchvision import transforms
import pydicom
import cv2
import pandas as pd
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
import matplotlib.pyplot as plt
import numpy as np

# Set the experiment name
# Restore the deleted experiment or create a new one
experiment_name = "new_experiment_name"  # Replace with a valid experiment name
mlflow.set_experiment(experiment_name)

# Specify the run ID of the logged model
run_id = "e2279f9e4abb43f9824a1ba402ce8168"  # Replace with your actual run ID
model_uri = f"runs:/{run_id}/model"

# Load the model
model = mlflow.pytorch.load_model(model_uri)
model.to(torch.device('cuda' if torch.cuda.is_available() else 'cpu'))  # Move model to appropriate device
model.eval()  # Set the model to evaluation mode

# Prepare data
transform = transforms.Compose([
    transforms.ToPILImage(),
    transforms.Resize((224, 224)),
    transforms.ColorJitter(brightness=0.2, contrast=0.2, saturation=0.2, hue=0.1),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
])

class MRIDataset(Dataset):
    def __init__(self, data, transform=None):
        self.data = data
        self.transform = transform
        self.data['severity'] = self.data['severity'].astype(int)

    def __getitem__(self, index):
        row = self.data.iloc[index]
        image_path = row['image_path']
        label = row['severity']
        dicom_image = pydicom.dcmread(image_path)
        image = dicom_image.pixel_array.astype(float)
        image = (image / image.max() * 255).astype('uint8')
        if len(image.shape) == 2:  # Grayscale
            image = cv2.cvtColor(image, cv2.COLOR_GRAY2RGB)
        image_tensor = self.transform(image) if self.transform else torch.from_numpy(image).permute(2, 0, 1)
        return image_tensor, torch.tensor(label).long()

    def __len__(self):
        return len(self.data)

# %% [markdown]
# predicting probabilities for test data

# %%
test_data = test_df

# %%
test_dataset = MRIDataset(data=test_data, transform=transform)
test_loader = DataLoader(test_dataset, batch_size=1, shuffle=False)

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print(f"Using device: {device}")

# Inference loop with probability extraction
results = []
probabilities_list = []

with torch.no_grad():
    for images, labels in test_loader:
        images = images.to(device)
        labels = labels.to(device)  # Ensure labels are also on the correct device
        outputs = model(images)
        probabilities = torch.softmax(outputs, dim=1)  # Calculate class probabilities
        _, predicted_classes = torch.max(outputs, 1)
        
        # Append predictions and probabilities
        results.append(predicted_classes.item())
        probabilities_list.append(probabilities.cpu().numpy())

# %%
# Print predicted classes and their probabilities
for i, (pred, probs) in enumerate(zip(results, probabilities_list)):
    print(f"Test image {i}: Predicted class {pred}, Probabilities: {probs}")

# Additional code to plot the confusion matrix can stay as-is:
true_labels = []
predicted_labels = []

for images, labels in test_loader:
    images = images.to(device)
    true_labels.extend(labels.numpy())

    with torch.no_grad():
        outputs = model(images)
        _, predicted_classes = torch.max(outputs, 1)
        predicted_labels.extend(predicted_classes.cpu().numpy())

true_labels = np.array(true_labels)
predicted_labels = np.array(predicted_labels)

print("True Labels Unique Values:", np.unique(true_labels))
print("Predicted Labels Unique Values:", np.unique(predicted_labels))
# Out:
# Test image 0: Predicted class 1, Probabilities: [[0.00464216 0.6964685  0.29888943]]
# Test image 1: Predicted class 2, Probabilities: [[1.3604683e-04 1.6012145e-02 9.8385185e-01]]
# Test image 2: Predicted class 1, Probabilities: [[0.00164388 0.99658304 0.00177316]]
# Test image 3: Predicted class 0, Probabilities: [[0.94493407 0.05271438 0.00235162]]
# Test image 4: Predicted class 0, Probabilities: [[5.4243630e-01 4.5735914e-01 2.0462088e-04]]
# Test image 5: Predicted class 0, Probabilities: [[9.8924482e-01 1.0617901e-02 1.3731277e-04]]
# Test image 6: Predicted class 1, Probabilities: [[1.6183108e-03 9.9837923e-01 2.5587524e-06]]
# Test image 7: Predicted class 0, Probabilities: [[0.824441   0.17376989 0.00178908]]
# Test image 8: Predicted class 1, Probabilities: [[3.0732277e-04 9.9923563e-01 4.5700610e-04]]
# Test image 9: Predicted class 1, Probabilities: [[8.0600905e-04 9.9761474e-01 1.5793140e-03]]
# Test image 10: Predicted class 0, Probabilities: [[9.9072534e-01 9.1857351e-03 8.8958237e-05]]
# Test image 11: Predicted class 1, Probabilities: [[4.0419003e-05 9.9993944e-01 2.0167541e-05]]
# Test image 12: Predicted class 2, Probabilities: [[1.5006941e-06 5.1122549e-04 9.9948728e-01]]
# Test image 13: Predicted class 2, Probabilities: [[7.3089330e-07 2.4707238e-05 9.9997461e-01]]
# Test image 14: Predicted class 1, Probabilities: [[6.4657149e-03 9.9348056e-01 5.3783799e-05]]
# Test image 15: Predicted class 2, Probabilities: [[0.00369561 0.3754612  0.62084323]]
# Test image 16: Predicted class 0, Probabilities: [[0.733893   0.24957736 0.0165297 ]]
# Test image 17: Predicted class 0, Probabilities: [[0.81891656 0.18025768 0.00082568]]
# Test image 18: Predicted class 2, Probabilities: [[2.0248346e-05 1.0611202e-03 9.9891865e-01]]
# Test image 19: Predicted class 1, Probabilities: [[1.5587966e-02 9.8423147e-01 1.8062156e-04]]
# Test image 20: Predicted class 2, Probabilities: [[6.8350101e-04 3.4688045e-03 9.9584770e-01]]
# Test image 21: Predicted class 1, Probabilities: [[0.00146698 0.9906369  0.00789622]]
# Test image 22: Predicted class 0, Probabilities: [[0.98117596 0.01723452 0.00158954]]
# Test image 23: Predicted class 2, Probabilities: [[5.3717476e-06 2.8233332e-04 9.9971229e-01]]
# Test image 24: Predicted class 1, Probabilities: [[0.36515686 0.4450881  0.18975507]]
# Test image 25: Predicted class 2, Probabilities: [[0.00875147 0.01103087 0.9802177 ]]
# Test image 26: Predicted class 1, Probabilities: [[1.6907303e-03 9.9822909e-01 8.0197562e-05]]
# Test image 27: Predicted class 2, Probabilities: [[0.00838688 0.01754328 0.9740699 ]]
# Test image 28: Predicted class 2, Probabilities: [[0.00055756 0.4994779  0.49996448]]
# Test image 29: Predicted class 1, Probabilities: [[4.0085545e-01 5.9903967e-01 1.0492898e-04]]
# Test image 125: Predicted class 2, Probabilities: [[3.0457668e-06 1.0812608e-05 9.9998617e-01]]
# Test image 126: Predicted class 2, Probabilities: [[0.00325903 0.0223687  0.9743723 ]]
# Test image 127: Predicted class 2, Probabilities: [[0.00636341 0.03581063 0.95782596]]
# Test image 128: Predicted class 2, Probabilities: [[4.3119525e-07 9.8791660e-04 9.9901164e-01]]
# Test image 129: Predicted class 1, Probabilities: [[0.00414364 0.9945117  0.00134462]]
# Test image 130: Predicted class 1, Probabilities: [[6.5402193e-03 9.9329787e-01 1.6182105e-04]]
# Test image 131: Predicted class 0, Probabilities: [[9.9826849e-01 1.5433456e-03 1.8818426e-04]]
# Test image 132: Predicted class 1, Probabilities: [[5.2514463e-03 9.9474156e-01 7.0223173e-06]]
# Test image 133: Predicted class 2, Probabilities: [[0.01513715 0.0227138  0.962149  ]]
# Test image 134: Predicted class 1, Probabilities: [[0.02687527 0.9699079  0.00321681]]
# Test image 135: Predicted class 0, Probabilities: [[9.9692756e-01 3.0011854e-03 7.1331291e-05]]
# Test image 136: Predicted class 2, Probabilities: [[0.00137931 0.08254243 0.9160782 ]]
# Test image 137: Predicted class 1, Probabilities: [[0.00139755 0.991347   0.00725544]]
# Test image 138: Predicted class 0, Probabilities: [[0.7000687  0.29890049 0.00103084]]
# Test image 139: Predicted class 1, Probabilities: [[3.4920878e-03 9.9647874e-01 2.9193921e-05]]
# Test image 140: Predicted class 1, Probabilities: [[0.16700268 0.58491117 0.24808605]]
# Test image 141: Predicted class 1, Probabilities: [[0.00169727 0.9965887  0.00171404]]
# Test image 142: Predicted class 0, Probabilities: [[0.6327685  0.36597136 0.00126006]]
# Test image 143: Predicted class 1, Probabilities: [[0.08612482 0.6970556  0.21681963]]
# Test image 144: Predicted class 1, Probabilities: [[5.3277804e-04 9.9795204e-01 1.5152082e-03]]
# Test image 145: Predicted class 2, Probabilities: [[8.6092645e-05 2.2324145e-02 9.7758979e-01]]
# Test image 146: Predicted class 2, Probabilities: [[1.3794141e-05 1.6152289e-03 9.9837095e-01]]
# Test image 147: Predicted class 0, Probabilities: [[0.7338995  0.20578492 0.06031565]]
# Test image 148: Predicted class 2, Probabilities: [[4.5728913e-05 2.1395523e-03 9.9781466e-01]]
# Test image 149: Predicted class 0, Probabilities: [[9.9255568e-01 7.1373316e-03 3.0708479e-04]]
# Test image 150: Predicted class 0, Probabilities: [[9.5475674e-01 4.4352829e-02 8.9048414e-04]]
# Test image 151: Predicted class 0, Probabilities: [[9.1027862e-01 8.9059144e-02 6.6222751e-04]]
# Test image 152: Predicted class 0, Probabilities: [[0.877427   0.11883557 0.00373752]]
# Test image 153: Predicted class 0, Probabilities: [[0.8022262  0.02068529 0.17708856]]
# Test image 154: Predicted class 2, Probabilities: [[0.01776543 0.11272492 0.86950964]]
# Test image 155: Predicted class 1, Probabilities: [[1.7022217e-03 9.9797040e-01 3.2736323e-04]]
# Test image 156: Predicted class 0, Probabilities: [[0.96597356 0.00503922 0.02898725]]
# Test image 157: Predicted class 2, Probabilities: [[0.00127368 0.01375512 0.9849712 ]]
# Test image 220: Predicted class 0, Probabilities: [[0.9663684 0.0322565 0.0013751]]
# Test image 221: Predicted class 2, Probabilities: [[0.0459906  0.13797486 0.8160345 ]]
# Test image 222: Predicted class 1, Probabilities: [[0.3056201  0.6935587  0.00082117]]
# Test image 223: Predicted class 1, Probabilities: [[0.11995471 0.870813   0.00923223]]
# Test image 224: Predicted class 0, Probabilities: [[9.2614996e-01 7.3846854e-02 3.2090550e-06]]
# Test image 225: Predicted class 2, Probabilities: [[0.00133577 0.03713796 0.9615263 ]]
# Test image 226: Predicted class 0, Probabilities: [[0.7365275  0.02114835 0.24232416]]
# Test image 227: Predicted class 0, Probabilities: [[0.9944834  0.00321943 0.00229719]]
# Test image 228: Predicted class 0, Probabilities: [[0.9817307  0.013396   0.00487332]]
# Test image 229: Predicted class 1, Probabilities: [[4.2910445e-01 5.7054597e-01 3.4955505e-04]]
# Test image 230: Predicted class 0, Probabilities: [[8.5500413e-01 1.4484988e-01 1.4592122e-04]]
# Test image 231: Predicted class 0, Probabilities: [[0.8883004  0.10544164 0.00625797]]
# Test image 232: Predicted class 1, Probabilities: [[0.00704873 0.98683804 0.00611315]]
# Test image 233: Predicted class 0, Probabilities: [[0.51189303 0.48435533 0.00375158]]
# Test image 234: Predicted class 2, Probabilities: [[6.308929e-05 9.505411e-02 9.048828e-01]]
# Test image 235: Predicted class 0, Probabilities: [[5.8565164e-01 4.1425419e-01 9.4170406e-05]]
# Test image 236: Predicted class 2, Probabilities: [[1.3388515e-06 1.8518523e-04 9.9981350e-01]]
# Test image 237: Predicted class 0, Probabilities: [[9.2916483e-01 7.0617504e-02 2.1767063e-04]]
# Test image 238: Predicted class 1, Probabilities: [[0.03108775 0.9648908  0.00402148]]
# Test image 239: Predicted class 1, Probabilities: [[1.6256607e-03 9.9822360e-01 1.5082431e-04]]
# Test image 240: Predicted class 0, Probabilities: [[0.9345979  0.04754123 0.01786078]]
# Test image 241: Predicted class 1, Probabilities: [[4.0590139e-03 9.9565327e-01 2.8772917e-04]]
# Test image 242: Predicted class 1, Probabilities: [[0.00990044 0.98861235 0.00148713]]
# Test image 243: Predicted class 2, Probabilities: [[8.898093e-06 1.622349e-02 9.837676e-01]]
# Test image 244: Predicted class 1, Probabilities: [[4.3864101e-03 9.9553287e-01 8.0678685e-05]]
# Test image 245: Predicted class 0, Probabilities: [[0.97225755 0.01835529 0.00938718]]
# Test image 246: Predicted class 1, Probabilities: [[0.00567534 0.9707634  0.02356127]]
# Test image 247: Predicted class 2, Probabilities: [[1.4957691e-04 4.5540249e-03 9.9529642e-01]]
# Test image 248: Predicted class 1, Probabilities: [[1.2573951e-02 9.8741156e-01 1.4500815e-05]]
# Test image 249: Predicted class 1, Probabilities: [[1.3865337e-01 8.6121756e-01 1.2909678e-04]]
# Test image 250: Predicted class 2, Probabilities: [[4.9495753e-05 1.1730609e-04 9.9983323e-01]]
# Test image 251: Predicted class 1, Probabilities: [[5.7036101e-05 9.8831254e-01 1.1630477e-02]]
# Test image 252: Predicted class 2, Probabilities: [[2.8487185e-07 2.2053577e-05 9.9997771e-01]]
# Test image 253: Predicted class 0, Probabilities: [[0.7977185  0.18109316 0.02118829]]
# Test image 254: Predicted class 1, Probabilities: [[1.6388034e-03 9.9809712e-01 2.6416124e-04]]
# Test image 255: Predicted class 1, Probabilities: [[0.00153434 0.9842247  0.01424102]]
# Test image 256: Predicted class 2, Probabilities: [[1.1242209e-04 5.2603185e-03 9.9462730e-01]]
# Test image 257: Predicted class 1, Probabilities: [[0.04127396 0.7791881  0.17953798]]
# Test image 258: Predicted class 0, Probabilities: [[0.8596746  0.13842525 0.00190022]]
# Test image 259: Predicted class 0, Probabilities: [[0.745684   0.14181851 0.11249755]]
# Test image 260: Predicted class 1, Probabilities: [[0.01156636 0.95747674 0.03095682]]
# Test image 261: Predicted class 2, Probabilities: [[3.7176150e-04 1.6890453e-03 9.9793917e-01]]
# Test image 262: Predicted class 1, Probabilities: [[0.05126348 0.945664   0.00307252]]
# Test image 263: Predicted class 2, Probabilities: [[2.6217633e-04 7.7773310e-04 9.9896014e-01]]
# Test image 264: Predicted class 1, Probabilities: [[0.00253691 0.996232   0.0012311 ]]
# Test image 265: Predicted class 2, Probabilities: [[4.3901656e-07 1.0031179e-04 9.9989927e-01]]
# Test image 266: Predicted class 0, Probabilities: [[0.98771054 0.00446324 0.00782627]]
# Test image 267: Predicted class 1, Probabilities: [[2.5226488e-03 9.9747485e-01 2.5363709e-06]]
# Test image 268: Predicted class 2, Probabilities: [[9.3080528e-04 2.7101442e-02 9.7196782e-01]]
# Test image 269: Predicted class 2, Probabilities: [[4.1840878e-05 2.5928630e-03 9.9736530e-01]]
# Test image 270: Predicted class 1, Probabilities: [[0.00384458 0.9949449  0.00121049]]
# Test image 271: Predicted class 2, Probabilities: [[6.4880674e-04 2.0345719e-01 7.9589397e-01]]
# Test image 272: Predicted class 2, Probabilities: [[7.5044859e-06 2.7670154e-05 9.9996483e-01]]
# Test image 273: Predicted class 2, Probabilities: [[3.8568887e-06 1.3600625e-03 9.9863607e-01]]
# Test image 274: Predicted class 2, Probabilities: [[9.608619e-07 9.031629e-05 9.999087e-01]]
# Test image 275: Predicted class 0, Probabilities: [[0.84621996 0.15211755 0.0016625 ]]
# Test image 276: Predicted class 1, Probabilities: [[1.5498562e-03 9.9774039e-01 7.0968014e-04]]
# Test image 277: Predicted class 2, Probabilities: [[1.0742959e-05 1.9590576e-04 9.9979335e-01]]
# Test image 278: Predicted class 2, Probabilities: [[0.00087061 0.4429918  0.5561377 ]]
# Test image 279: Predicted class 1, Probabilities: [[2.6275043e-03 9.9710852e-01 2.6398644e-04]]
# Test image 280: Predicted class 1, Probabilities: [[0.32587028 0.64825726 0.02587237]]
# Test image 281: Predicted class 1, Probabilities: [[0.0036068  0.99402267 0.00237051]]
# Test image 282: Predicted class 0, Probabilities: [[0.6039425  0.35678452 0.03927302]]
# Test image 283: Predicted class 1, Probabilities: [[1.6796449e-03 9.9831641e-01 3.9484362e-06]]
# Test image 412: Predicted class 2, Probabilities: [[1.2797942e-04 4.3475967e-02 9.5639604e-01]]
# Test image 413: Predicted class 2, Probabilities: [[7.6043079e-06 7.0266612e-04 9.9928975e-01]]
# Test image 414: Predicted class 0, Probabilities: [[9.9460876e-01 4.7025494e-03 6.8859651e-04]]
# Test image 415: Predicted class 0, Probabilities: [[9.9604416e-01 3.6437877e-03 3.1208547e-04]]
# Test image 416: Predicted class 2, Probabilities: [[8.0595171e-04 3.0212151e-03 9.9617285e-01]]
# Test image 417: Predicted class 1, Probabilities: [[1.3018966e-03 9.9805558e-01 6.4257719e-04]]
# Test image 418: Predicted class 2, Probabilities: [[7.0991351e-05 3.7067097e-03 9.9622226e-01]]
# Test image 419: Predicted class 2, Probabilities: [[0.02700912 0.00573676 0.9672541 ]]
# Test image 420: Predicted class 2, Probabilities: [[0.01904037 0.06649495 0.9144647 ]]
# Test image 421: Predicted class 0, Probabilities: [[0.9529768  0.0020979  0.04492525]]
# Test image 422: Predicted class 0, Probabilities: [[8.0615592e-01 1.9378099e-01 6.3026979e-05]]
# Test image 423: Predicted class 0, Probabilities: [[9.4705963e-01 5.2742392e-02 1.9798140e-04]]
# Test image 424: Predicted class 2, Probabilities: [[1.1394907e-06 4.4955195e-05 9.9995387e-01]]
# Test image 425: Predicted class 2, Probabilities: [[0.08714534 0.10621567 0.80663896]]
# Test image 426: Predicted class 0, Probabilities: [[0.9253507  0.05303504 0.02161425]]
# Test image 427: Predicted class 2, Probabilities: [[0.00556829 0.00664686 0.98778486]]
# Test image 428: Predicted class 0, Probabilities: [[0.7255717 0.2731465 0.0012818]]
# Test image 429: Predicted class 0, Probabilities: [[0.7788995  0.22005993 0.00104059]]
# Test image 430: Predicted class 0, Probabilities: [[9.5527601e-01 4.4723328e-02 6.2838023e-07]]
# Test image 431: Predicted class 1, Probabilities: [[0.09458721 0.8467616  0.05865118]]
# Test image 432: Predicted class 2, Probabilities: [[0.04939343 0.26017046 0.6904361 ]]
# Test image 433: Predicted class 2, Probabilities: [[0.00168136 0.09145448 0.90686417]]
# Test image 434: Predicted class 0, Probabilities: [[0.77915627 0.21790138 0.00294234]]
# Test image 435: Predicted class 0, Probabilities: [[0.95614773 0.04267114 0.00118125]]
# Test image 436: Predicted class 2, Probabilities: [[1.3775439e-06 8.6767873e-04 9.9913090e-01]]
# Test image 437: Predicted class 1, Probabilities: [[5.1968176e-02 9.4755191e-01 4.7993974e-04]]
# Test image 438: Predicted class 2, Probabilities: [[6.0618845e-07 2.4719946e-05 9.9997473e-01]]
# Test image 439: Predicted class 2, Probabilities: [[3.0483372e-04 1.2878823e-02 9.8681635e-01]]
# Test image 440: Predicted class 2, Probabilities: [[3.6750294e-05 9.6281461e-04 9.9900049e-01]]
# Test image 441: Predicted class 0, Probabilities: [[0.69341654 0.305691   0.00089246]]
# Test image 442: Predicted class 0, Probabilities: [[9.0784407e-01 9.2125185e-02 3.0712534e-05]]
# Test image 443: Predicted class 1, Probabilities: [[5.7093427e-03 9.9342030e-01 8.7035366e-04]]
# Test image 444: Predicted class 1, Probabilities: [[4.0193489e-03 9.9589634e-01 8.4291125e-05]]
# Test image 445: Predicted class 1, Probabilities: [[1.8066151e-02 9.8190743e-01 2.6443433e-05]]
# Test image 446: Predicted class 2, Probabilities: [[6.7924120e-05 1.5415035e-03 9.9839056e-01]]
# Test image 447: Predicted class 1, Probabilities: [[0.33747622 0.6556367  0.00688707]]
# Test image 448: Predicted class 2, Probabilities: [[2.2973560e-04 3.3700212e-03 9.9640024e-01]]
# Test image 449: Predicted class 0, Probabilities: [[9.690151e-01 3.086786e-02 1.170428e-04]]
# Test image 450: Predicted class 1, Probabilities: [[2.1769259e-04 9.9257553e-01 7.2067715e-03]]
# Test image 451: Predicted class 0, Probabilities: [[0.89346045 0.09664168 0.0098979 ]]
# Test image 452: Predicted class 1, Probabilities: [[5.0579943e-03 9.9493825e-01 3.7758027e-06]]
# Test image 453: Predicted class 2, Probabilities: [[4.3092085e-05 1.1283620e-04 9.9984407e-01]]
# Test image 454: Predicted class 0, Probabilities: [[0.74464786 0.23853396 0.01681812]]
# Test image 455: Predicted class 2, Probabilities: [[0.0499276  0.03790243 0.91217   ]]
# Test image 456: Predicted class 1, Probabilities: [[0.28650075 0.6720199  0.04147943]]
# Test image 457: Predicted class 0, Probabilities: [[9.9422860e-01 4.9999957e-03 7.7142991e-04]]
# Test image 458: Predicted class 2, Probabilities: [[0.00105755 0.0224365  0.97650594]]
# Test image 459: Predicted class 2, Probabilities: [[1.1138268e-05 2.9629476e-03 9.9702591e-01]]
# Test image 460: Predicted class 1, Probabilities: [[0.00102319 0.9909741  0.00800274]]
# Test image 461: Predicted class 0, Probabilities: [[9.5710611e-01 4.2288583e-02 6.0522638e-04]]
# Test image 462: Predicted class 1, Probabilities: [[0.41603318 0.57666236 0.00730439]]
# Test image 463: Predicted class 1, Probabilities: [[0.00810112 0.9903769  0.00152201]]
# Test image 464: Predicted class 1, Probabilities: [[6.275055e-04 9.936073e-01 5.765213e-03]]
# Test image 465: Predicted class 0, Probabilities: [[9.4459563e-01 5.4926872e-02 4.7758399e-04]]
# Test image 466: Predicted class 1, Probabilities: [[0.02419931 0.9682739  0.00752681]]
# Test image 467: Predicted class 2, Probabilities: [[5.091319e-04 4.909424e-02 9.503966e-01]]
# Test image 468: Predicted class 2, Probabilities: [[0.01676571 0.06766197 0.9155723 ]]
# Test image 469: Predicted class 2, Probabilities: [[1.2939218e-04 2.1523160e-03 9.9771833e-01]]
# Test image 470: Predicted class 1, Probabilities: [[4.3141721e-05 9.9988425e-01 7.2607480e-05]]
# Test image 471: Predicted class 0, Probabilities: [[0.9575736  0.04094451 0.00148194]]
# Test image 472: Predicted class 0, Probabilities: [[0.9670784  0.03050895 0.00241272]]
# Test image 473: Predicted class 2, Probabilities: [[6.8719040e-05 1.8004526e-03 9.9813086e-01]]
# Test image 474: Predicted class 1, Probabilities: [[0.43917105 0.5592309  0.00159795]]
# Test image 475: Predicted class 0, Probabilities: [[0.8177705  0.17970473 0.00252481]]
# Test image 476: Predicted class 2, Probabilities: [[2.6326245e-05 1.7758611e-03 9.9819785e-01]]
# Test image 477: Predicted class 0, Probabilities: [[0.9471352  0.03832538 0.0145394 ]]
# Test image 478: Predicted class 2, Probabilities: [[0.07767694 0.11172493 0.81059813]]
# Test image 479: Predicted class 0, Probabilities: [[0.95993525 0.03860623 0.00145852]]
# Test image 480: Predicted class 0, Probabilities: [[0.8729276  0.12275214 0.00432034]]
# Test image 481: Predicted class 1, Probabilities: [[1.583873e-03 9.984091e-01 7.024540e-06]]
# Test image 482: Predicted class 0, Probabilities: [[0.80006206 0.03202026 0.16791773]]
# Test image 483: Predicted class 2, Probabilities: [[1.2490974e-05 7.0052448e-04 9.9928707e-01]]
# Test image 484: Predicted class 0, Probabilities: [[7.6727951e-01 2.3263629e-01 8.4112915e-05]]
# Test image 485: Predicted class 1, Probabilities: [[6.6308461e-02 9.3357402e-01 1.1754114e-04]]
# Test image 486: Predicted class 2, Probabilities: [[1.149348e-04 8.502788e-03 9.913823e-01]]
# Test image 487: Predicted class 0, Probabilities: [[0.9493375  0.04310112 0.0075614 ]]
# Test image 488: Predicted class 1, Probabilities: [[1.4953249e-03 9.9816471e-01 3.3995920e-04]]
# Test image 489: Predicted class 2, Probabilities: [[8.5004774e-07 9.9078834e-04 9.9900836e-01]]
# Test image 490: Predicted class 1, Probabilities: [[0.04162691 0.9563554  0.00201768]]
# Test image 491: Predicted class 1, Probabilities: [[0.00274744 0.9913685  0.00588403]]
# Test image 492: Predicted class 0, Probabilities: [[0.91486263 0.08027743 0.00485993]]
# Test image 493: Predicted class 0, Probabilities: [[0.7587459  0.24046247 0.00079165]]
# Test image 494: Predicted class 1, Probabilities: [[2.7686337e-03 9.9662507e-01 6.0623692e-04]]
# Test image 495: Predicted class 1, Probabilities: [[4.1989922e-03 9.9499965e-01 8.0140657e-04]]
# Test image 496: Predicted class 0, Probabilities: [[9.9943990e-01 4.1775825e-04 1.4242016e-04]]
# Test image 497: Predicted class 1, Probabilities: [[8.3194464e-04 9.9885023e-01 3.1781435e-04]]
# Test image 498: Predicted class 1, Probabilities: [[3.8649462e-02 9.6095580e-01 3.9476209e-04]]
# Test image 499: Predicted class 2, Probabilities: [[1.7167229e-04 7.0089870e-04 9.9912745e-01]]
# Test image 500: Predicted class 0, Probabilities: [[0.5205556  0.47166213 0.00778225]]
# Test image 501: Predicted class 1, Probabilities: [[1.5029786e-04 9.9389064e-01 5.9589804e-03]]
# Test image 502: Predicted class 1, Probabilities: [[0.0384269  0.955507   0.00606618]]
# Test image 503: Predicted class 1, Probabilities: [[0.00346041 0.9850765  0.01146308]]
# Test image 504: Predicted class 0, Probabilities: [[8.78773630e-01 1.21149555e-01 7.67400052e-05]]
# Test image 505: Predicted class 1, Probabilities: [[0.00221622 0.99424404 0.00353974]]
# Test image 506: Predicted class 2, Probabilities: [[3.2771750e-06 5.7993256e-03 9.9419737e-01]]
# Test image 507: Predicted class 2, Probabilities: [[7.9234491e-07 7.3325726e-05 9.9992585e-01]]
# Test image 508: Predicted class 2, Probabilities: [[2.3052223e-06 1.5986031e-04 9.9983776e-01]]
# Test image 509: Predicted class 1, Probabilities: [[4.1403398e-02 9.5796746e-01 6.2910258e-04]]
# Test image 510: Predicted class 1, Probabilities: [[6.9122593e-04 9.9930549e-01 3.3187846e-06]]
# Test image 511: Predicted class 2, Probabilities: [[4.0024233e-07 2.4386552e-04 9.9975568e-01]]
# Test image 512: Predicted class 0, Probabilities: [[9.8915303e-01 6.6847494e-04 1.0178577e-02]]
# Test image 513: Predicted class 1, Probabilities: [[1.8871606e-04 9.9980909e-01 2.2523070e-06]]
# Test image 514: Predicted class 0, Probabilities: [[0.5544672  0.441334   0.00419875]]
# Test image 515: Predicted class 0, Probabilities: [[7.1552336e-01 2.8379166e-01 6.8492128e-04]]
# Test image 516: Predicted class 2, Probabilities: [[2.2053080e-06 4.2102572e-05 9.9995565e-01]]
# Test image 517: Predicted class 2, Probabilities: [[3.2640327e-07 6.5677241e-06 9.9999309e-01]]
# Test image 518: Predicted class 2, Probabilities: [[4.1774945e-07 2.2386188e-05 9.9997723e-01]]
# Test image 519: Predicted class 2, Probabilities: [[7.982043e-05 6.954115e-04 9.992248e-01]]
# Test image 520: Predicted class 0, Probabilities: [[9.8686206e-01 1.2406120e-02 7.3176564e-04]]
# Test image 521: Predicted class 1, Probabilities: [[9.1120061e-03 9.9013430e-01 7.5361977e-04]]
# Test image 522: Predicted class 2, Probabilities: [[0.00778108 0.00905559 0.9831633 ]]
# ...
# Test image 4681: Predicted class 2, Probabilities: [[1.063099e-05 7.013223e-04 9.992880e-01]]
# Test image 4682: Predicted class 0, Probabilities: [[0.9838538  0.01427355 0.00187269]]
# Test image 4683: Predicted class 2, Probabilities: [[0.0173775  0.00425003 0.9783725 ]]
# Test image 4684: Predicted class 0, Probabilities: [[9.9721885e-01 2.7683727e-03 1.2664945e-05]]
# Test image 4685: Predicted class 1, Probabilities: [[0.04741482 0.8308078  0.12177747]]
# Test image 4686: Predicted class 0, Probabilities: [[0.8716949  0.12540863 0.0028964 ]]
# Test image 4687: Predicted class 0, Probabilities: [[0.6223648  0.31919265 0.05844246]]
# Test image 4688: Predicted class 2, Probabilities: [[0.00156637 0.01203249 0.98640114]]
# Test image 4689: Predicted class 2, Probabilities: [[6.5325247e-04 1.0297234e-03 9.9831700e-01]]
# Test image 4690: Predicted class 1, Probabilities: [[6.1300828e-04 9.9927717e-01 1.0982471e-04]]
# Test image 4691: Predicted class 1, Probabilities: [[0.36635393 0.6277323  0.00591377]]
# Test image 4692: Predicted class 2, Probabilities: [[2.6956170e-05 4.3095066e-03 9.9566358e-01]]
# Test image 4693: Predicted class 2, Probabilities: [[3.7678547e-04 1.9303510e-01 8.0658805e-01]]
# Test image 4694: Predicted class 1, Probabilities: [[0.03437952 0.9596301  0.00599037]]
# Test image 4695: Predicted class 2, Probabilities: [[6.5740501e-04 2.4200417e-03 9.9692255e-01]]
# Test image 4696: Predicted class 2, Probabilities: [[3.6575363e-04 1.3192011e-03 9.9831510e-01]]
# Test image 4728: Predicted class 1, Probabilities: [[0.02217035 0.9623081  0.01552154]]
# Test image 4729: Predicted class 2, Probabilities: [[2.0114103e-04 1.9205214e-02 9.8059362e-01]]
# Test image 4730: Predicted class 1, Probabilities: [[1.3618955e-03 9.9846494e-01 1.7323857e-04]]
# Test image 4731: Predicted class 2, Probabilities: [[3.8074333e-05 1.2514890e-03 9.9871039e-01]]
# Test image 4732: Predicted class 2, Probabilities: [[5.0997647e-07 3.0078860e-05 9.9996936e-01]]
# Test image 4733: Predicted class 2, Probabilities: [[6.7854686e-05 6.1619317e-04 9.9931598e-01]]
# Test image 4734: Predicted class 2, Probabilities: [[5.59620275e-06 1.12142395e-02 9.88780141e-01]]
# Test image 4735: Predicted class 1, Probabilities: [[0.00197282 0.81228673 0.18574034]]
# Test image 4736: Predicted class 2, Probabilities: [[4.5687318e-04 2.6451352e-03 9.9689794e-01]]
# Test image 4737: Predicted class 0, Probabilities: [[0.82808805 0.16488959 0.00702238]]
# Test image 4738: Predicted class 2, Probabilities: [[1.4312115e-05 1.8631472e-03 9.9812251e-01]]
# Test image 4739: Predicted class 0, Probabilities: [[8.2967144e-01 1.6995354e-01 3.7505708e-04]]
# Test image 4740: Predicted class 1, Probabilities: [[0.01284802 0.9755445  0.01160739]]
# Test image 4741: Predicted class 0, Probabilities: [[9.4213259e-01 5.7627287e-02 2.4014391e-04]]
# Test image 4742: Predicted class 2, Probabilities: [[1.3878796e-04 1.4512307e-03 9.9840999e-01]]
# Test image 4743: Predicted class 2, Probabilities: [[6.2303366e-06 2.0654502e-04 9.9978727e-01]]
# Test image 4744: Predicted class 0, Probabilities: [[0.85384154 0.144815   0.00134348]]
# Test image 4745: Predicted class 1, Probabilities: [[1.5323836e-02 9.8433208e-01 3.4408958e-04]]
# Test image 4746: Predicted class 1, Probabilities: [[0.06230108 0.9337912  0.00390766]]
# Test image 4747: Predicted class 2, Probabilities: [[4.1456551e-05 6.6181151e-03 9.9334043e-01]]
# Test image 4748: Predicted class 1, Probabilities: [[8.0668293e-03 9.9184251e-01 9.0647554e-05]]
# Test image 4749: Predicted class 1, Probabilities: [[3.2720980e-03 9.9672663e-01 1.3241820e-06]]
# Test image 4750: Predicted class 0, Probabilities: [[9.9140513e-01 8.5265450e-03 6.8278125e-05]]
# Test image 4751: Predicted class 2, Probabilities: [[7.3633491e-05 4.6680016e-03 9.9525839e-01]]
# Test image 4752: Predicted class 2, Probabilities: [[0.17990568 0.03103013 0.7890642 ]]
# Test image 4753: Predicted class 1, Probabilities: [[0.00254385 0.9929259  0.00453036]]
# Test image 4754: Predicted class 1, Probabilities: [[0.00201078 0.9272794  0.07070993]]
# Test image 4755: Predicted class 1, Probabilities: [[9.479390e-03 9.902761e-01 2.444232e-04]]
# Test image 4756: Predicted class 1, Probabilities: [[1.7062319e-03 9.9822730e-01 6.6570246e-05]]
# Test image 4757: Predicted class 1, Probabilities: [[0.01616874 0.6422314  0.34159982]]
# Test image 4758: Predicted class 1, Probabilities: [[1.4290542e-03 9.9855214e-01 1.8789866e-05]]
# Test image 4759: Predicted class 1, Probabilities: [[0.13039584 0.86719435 0.00240971]]
# Test image 4760: Predicted class 2, Probabilities: [[4.0396371e-05 2.3505953e-04 9.9972457e-01]]
# Test image 4761: Predicted class 1, Probabilities: [[0.41167742 0.58713233 0.00119019]]
# Test image 4762: Predicted class 0, Probabilities: [[9.8429072e-01 1.5587775e-02 1.2146753e-04]]
# Test image 4763: Predicted class 2, Probabilities: [[9.5774914e-05 1.5529002e-03 9.9835134e-01]]
# Test image 4764: Predicted class 1, Probabilities: [[2.4016332e-03 9.9665618e-01 9.4220188e-04]]
# Test image 4765: Predicted class 0, Probabilities: [[0.7104839  0.25133672 0.03817937]]
# Test image 4766: Predicted class 1, Probabilities: [[0.00121799 0.9946515  0.00413058]]
# Test image 4767: Predicted class 0, Probabilities: [[0.7970532  0.19042876 0.01251799]]
# Test image 4768: Predicted class 0, Probabilities: [[0.9277694  0.01336824 0.0588623 ]]
# Test image 4769: Predicted class 2, Probabilities: [[6.6884462e-04 1.2375063e-01 8.7558055e-01]]
# Test image 4770: Predicted class 0, Probabilities: [[0.83713263 0.16180101 0.00106642]]
# Test image 4771: Predicted class 0, Probabilities: [[9.8823929e-01 1.1628313e-02 1.3238637e-04]]
# Test image 4772: Predicted class 1, Probabilities: [[4.7202772e-03 9.9520653e-01 7.3211500e-05]]
# Test image 4773: Predicted class 2, Probabilities: [[1.1461723e-05 1.3296658e-03 9.9865890e-01]]
# Test image 4774: Predicted class 1, Probabilities: [[4.0600759e-01 5.9384239e-01 1.5008694e-04]]
# Test image 4775: Predicted class 1, Probabilities: [[4.1174646e-03 9.9579585e-01 8.6693144e-05]]
# Test image 4776: Predicted class 0, Probabilities: [[9.956340e-01 3.816249e-03 5.497757e-04]]
# Test image 4777: Predicted class 1, Probabilities: [[0.00642276 0.9815678  0.01200941]]
# Test image 4778: Predicted class 2, Probabilities: [[6.1639167e-07 2.1427273e-05 9.9997795e-01]]
# Test image 4779: Predicted class 2, Probabilities: [[1.15295225e-04 1.96894383e-04 9.99687791e-01]]
# Test image 4780: Predicted class 2, Probabilities: [[2.5529732e-07 4.9971091e-04 9.9950004e-01]]
# Test image 4781: Predicted class 1, Probabilities: [[1.0677102e-02 9.8931527e-01 7.6646947e-06]]
# Test image 4782: Predicted class 1, Probabilities: [[5.4528349e-04 9.9762028e-01 1.8344643e-03]]
# Test image 4783: Predicted class 2, Probabilities: [[1.5010465e-07 2.2673950e-05 9.9997723e-01]]
# Test image 4784: Predicted class 1, Probabilities: [[1.1109438e-02 9.8883772e-01 5.2816522e-05]]
# Test image 4785: Predicted class 1, Probabilities: [[3.0666976e-03 9.9598616e-01 9.4713509e-04]]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[12], line 14
#      11 true_labels.extend(labels.numpy())
#      13 with torch.no_grad():
# ---> 14     outputs = model(images)
#      15     _, predicted_classes = torch.max(outputs, 1)
#      16     predicted_labels.extend(predicted_classes.cpu().numpy())
#
# File c:\Users\HP1\Desktop\Spiced\capstone-project\.venv\Lib\site-packages\torch\nn\modules\module.py:1736, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1734     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1735 else:
# -> 1736     return self._call_impl(*args, **kwargs)
#
# File c:\Users\HP1\Desktop\Spiced\capstone-project\.venv\Lib\site-packages\torch\nn\modules\module.py:1747, in Module._call_impl(self, *args, **kwargs)
#    1742 # If we don't have any hooks, we want to skip the rest of the logic in
#    1743 # this function, and just call forward.
#    1744 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1745         or _global_backward_pre_hooks or _global_backward_hooks
#    1746         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1747     return forward_call(*args, **kwargs)
#    1749 result = None
#    1750 called_always_called_hooks = set()
#
# File c:\Users\HP1\Desktop\Spiced\capstone-project\.venv\Lib\site-packages\torchvision\models\resnet.py:285, in ResNet.forward(self, x)
#     284 def forward(self, x: Tensor) -> Tensor:
# --> 285     return self._forward_impl(x)
#
# File c:\Users\HP1\Desktop\Spiced\capstone-project\.venv\Lib\site-packages\torchvision\models\resnet.py:275, in ResNet._forward_impl(self, x)
#     273 x = self.layer1(x)
#     274 x = self.layer2(x)
# --> 275 x = self.layer3(x)
#     276 x = self.layer4(x)
#     278 x = self.avgpool(x)
#
# File c:\Users\HP1\Desktop\Spiced\capstone-project\.venv\Lib\site-packages\torch\nn\modules\module.py:1736, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1734     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1735 else:
# -> 1736     return self._call_impl(*args, **kwargs)
#
# File c:\Users\HP1\Desktop\Spiced\capstone-project\.venv\Lib\site-packages\torch\nn\modules\module.py:1747, in Module._call_impl(self, *args, **kwargs)
#    1742 # If we don't have any hooks, we want to skip the rest of the logic in
#    1743 # this function, and just call forward.
#    1744 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1745         or _global_backward_pre_hooks or _global_backward_hooks
#    1746         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1747     return forward_call(*args, **kwargs)
#    1749 result = None
#    1750 called_always_called_hooks = set()
#
# File c:\Users\HP1\Desktop\Spiced\capstone-project\.venv\Lib\site-packages\torch\nn\modules\container.py:250, in Sequential.forward(self, input)
#     248 def forward(self, input):
#     249     for module in self:
# --> 250         input = module(input)
#     251     return input
#
# File c:\Users\HP1\Desktop\Spiced\capstone-project\.venv\Lib\site-packages\torch\nn\modules\module.py:1736, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1734     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1735 else:
# -> 1736     return self._call_impl(*args, **kwargs)
#
# File c:\Users\HP1\Desktop\Spiced\capstone-project\.venv\Lib\site-packages\torch\nn\modules\module.py:1747, in Module._call_impl(self, *args, **kwargs)
#    1742 # If we don't have any hooks, we want to skip the rest of the logic in
#    1743 # this function, and just call forward.
#    1744 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1745         or _global_backward_pre_hooks or _global_backward_hooks
#    1746         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1747     return forward_call(*args, **kwargs)
#    1749 result = None
#    1750 called_always_called_hooks = set()
#
# File c:\Users\HP1\Desktop\Spiced\capstone-project\.venv\Lib\site-packages\torchvision\models\resnet.py:150, in Bottleneck.forward(self, x)
#     147 out = self.bn1(out)
#     148 out = self.relu(out)
# --> 150 out = self.conv2(out)
#     151 out = self.bn2(out)
#     152 out = self.relu(out)
#
# File c:\Users\HP1\Desktop\Spiced\capstone-project\.venv\Lib\site-packages\torch\nn\modules\module.py:1736, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1734     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1735 else:
# -> 1736     return self._call_impl(*args, **kwargs)
#
# File c:\Users\HP1\Desktop\Spiced\capstone-project\.venv\Lib\site-packages\torch\nn\modules\module.py:1747, in Module._call_impl(self, *args, **kwargs)
#    1742 # If we don't have any hooks, we want to skip the rest of the logic in
#    1743 # this function, and just call forward.
#    1744 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1745         or _global_backward_pre_hooks or _global_backward_hooks
#    1746         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1747     return forward_call(*args, **kwargs)
#    1749 result = None
#    1750 called_always_called_hooks = set()
#
# File c:\Users\HP1\Desktop\Spiced\capstone-project\.venv\Lib\site-packages\torch\nn\modules\conv.py:554, in Conv2d.forward(self, input)
#     553 def forward(self, input: Tensor) -> Tensor:
# --> 554     return self._conv_forward(input, self.weight, self.bias)
#
# File c:\Users\HP1\Desktop\Spiced\capstone-project\.venv\Lib\site-packages\torch\nn\modules\conv.py:549, in Conv2d._conv_forward(self, input, weight, bias)
#     537 if self.padding_mode != "zeros":
#     538     return F.conv2d(
#     539         F.pad(
#     540             input, self._reversed_padding_repeated_twice, mode=self.padding_mode
#    (...)
#     547         self.groups,
#     548     )
# --> 549 return F.conv2d(
#     550     input, weight, bias, self.stride, self.padding, self.dilation, self.groups
#     551 )
#
# KeyboardInterrupt:

# %%
# Convert the list of probabilities to a numpy array for easier manipulation
probabilities_array = np.vstack(probabilities_list)

# Ensure the length of probabilities_array matches the length of test_df
probabilities_array = probabilities_array[:len(test_df)]

# Add the probabilities to the test_df DataFrame
test_df['Probability_Class_0'] = probabilities_array[:, 0]
test_df['Probability_Class_1'] = probabilities_array[:, 1]
test_df['Probability_Class_2'] = probabilities_array[:, 2]

# Round the probabilities to 4 decimal places
test_df['Probability_Class_0'] = test_df['Probability_Class_0'].round(4)
test_df['Probability_Class_1'] = test_df['Probability_Class_1'].round(4)
test_df['Probability_Class_2'] = test_df['Probability_Class_2'].round(4)
# Add the predicted classes to the test_df DataFrame
test_df['Predicted_Class'] = results



# Display the updated DataFrame
 
test_df.head()

# %%
# Group by severity and sum the Probability_Class_1
severity_prob_sum_all_classes = test_df.groupby('severity')[['Probability_Class_0', 'Probability_Class_1', 'Probability_Class_2']].mean()

# Print the result
severity_prob_sum_all_classes
# Use severity_prob_sum_all_classes as confusion matrix
conf_matrix_prob_df = severity_prob_sum_all_classes 
# Create a confusion matrix from severity and predicted class
conf_matrix_severity_pred = confusion_matrix(test_df['severity'], test_df['Predicted_Class'])

# Create a DataFrame from the confusion matrix
conf_matrix_severity_pred_df = pd.DataFrame(
    conf_matrix_severity_pred, 
    index=[f"Actual {i}" for i in range(len(conf_matrix_severity_pred))], 
    columns=[f"Predicted {i}" for i in range(len(conf_matrix_severity_pred[0]))]
)

# Print the confusion matrix DataFrame
print(conf_matrix_severity_pred_df)

# Optionally, display it using a more formatted view (e.g., in Jupyter Notebook)
conf_matrix_severity_pred_df.style.background_gradient(cmap='Blues')
# Print the confusion matrix DataFrame
print(conf_matrix_prob_df)

# Optionally, display it using a more formatted view (e.g., in Jupyter Notebook)
conf_matrix_prob_df.style.background_gradient(cmap='Blues')

# %%
conf_matrix_severity_pred_df.style.background_gradient(cmap='Blues')

# %%
from sklearn.metrics import confusion_matrix
import pandas as pd
import numpy as np

# Ensure true_labels and predicted_labels have the same length
min_length = min(len(true_labels), len(predicted_labels))
true_labels = true_labels[:min_length]
predicted_labels = predicted_labels[:min_length]

# Generate the confusion matrix
conf_matrix = confusion_matrix(true_labels, predicted_labels)

# Create a DataFrame from the confusion matrix
conf_matrix_df = pd.DataFrame(
    conf_matrix, 
    index=[f"Actual {i}" for i in range(len(conf_matrix))], 
    columns=[f"Predicted {i}" for i in range(len(conf_matrix[0]))]
)

# Print the confusion matrix DataFrame
print(conf_matrix_df)

# Optionally, display it using a more formatted view (e.g., in Jupyter Notebook)
conf_matrix_df.style.background_gradient(cmap='Blues')

# %%
from sklearn.metrics import precision_score, recall_score, accuracy_score
# Calculate precision, recall, and accuracy using mean_probabilities_df
precision = precision_score(true_labels, predicted_labels, average='weighted')
recall = recall_score(true_labels, predicted_labels, average='weighted')
accuracy = accuracy_score(true_labels, predicted_labels)

print(f"Precision: {precision:.4f}")
print(f"Recall: {recall:.4f}")
print(f"Accuracy: {accuracy:.4f}")
