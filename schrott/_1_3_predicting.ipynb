# %% [markdown]
# Packages:

# %%
import glob
import os
import warnings


import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

import pydicom
from pydicom.data import get_testdata_files
from sklearn.model_selection import train_test_split

from IPython.display import Markdown, display

 # Import functions from the module
import importlib
import help_files._0_definitions 
import  help_files._1_visuals_script
# import  help_files._01_load_data
 # Reload the module to apply the changes to the script
importlib.reload(help_files._0_definitions)
importlib.reload(help_files._1_visuals_script)
# importlib.reload(help_files._01_load_data)
import  help_files._1_visuals_script  as pauls_vs
# Group by 'condition', 'level', and 'severity' and count occurrences
from help_files._0_definitions import count_severity_by_condition_level 
# Define the path
from pathlib import Path

pd.set_option("display.width", 1000)  # Set a large width to prevent line wrapping

# %%
### In definitions are all the functions that are used in the notebook and globals
with open("help_files/_0_definitions.py") as file:
    exec(file.read())

# %%
# Save the filtered dataframes to CSV files
dataframes = ["df_end"]
file_names = ["df_end.csv"]
 
# Load the data from _01_load_data
dataframes = [pd.read_csv(data_path_vor / file_name) for file_name in file_names]
df_end = dataframes[0]

# %%
df_end.dtypes
# Out:
# study_id        int64
# severity      float64
# condition       int64
# level          object
# series_id     float64
# x             float64
# y             float64
# image_path     object
# dtype: object

# %% [markdown]
# first try

# %%
# Randomly sample 100 rows from random_samples_combined
random_samples_test_check = df_end.sample(n=100, random_state=RSEED)
random_samples_test_check
# Out:
#         study_id  severity  condition  level     series_id           x           y                                         image_path
# 1801  2543001868       1.0          0  l5/s1  7.878829e+08  282.233215  309.144876  data/train_images_origin/2543001868/1289783254...
# 1190  1698156042       2.0          0  l5/s1  1.349877e+09  178.912134  213.389121  data/train_images_origin/1698156042/3800217841...
# 1817  2568819355       0.0          0  l5/s1  6.402851e+08  360.224323  568.235013  data/train_images_origin/2568819355/4223104020...
# 251    358286753       2.0          0  l5/s1  1.392935e+09  133.461942  246.570393  data/train_images_origin/358286753/4144723093/...
# 2505  3515641631       1.0          0  l5/s1  3.168174e+09  408.250460  550.081594  data/train_images_origin/3515641631/4119560068...
# ...          ...       ...        ...    ...           ...         ...         ...                                                ...
# 416    607436629       0.0          0  l5/s1  4.274491e+09  208.310903  246.131231  data/train_images_origin/607436629/493360101/5...
# 2631  3742728457       0.0          0  l5/s1  2.064758e+09  169.131790  266.956346  data/train_images_origin/3742728457/4105399347...
# 2291  3239069834       1.0          0  l5/s1  2.276407e+09  233.190776  394.465409  data/train_images_origin/3239069834/2352610120...
# 174    286903519       0.0          0  l5/s1  1.527286e+09  229.419524  316.628781  data/train_images_origin/286903519/1921917205/...
# 1725  2466046363       1.0          0  l5/s1  1.411326e+09  306.013271  352.907096  data/train_images_origin/2466046363/1478301987...
#
# [100 rows x 8 columns]

# %% [markdown]
# Restore parameters and metrtics from mlflow

# %% [markdown]
# I should take prdicted probabilities and not predicted classes: output scores (logits) are converted into probabilities using the softmax function

# %%
import mlflow
import mlflow.pytorch
import torch
from torch import nn, optim
from torch.utils.data import Dataset, DataLoader, random_split
import torchvision.models as models
from torchvision import transforms
import pydicom
import cv2
import pandas as pd
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
import matplotlib.pyplot as plt
import numpy as np

# Set the experiment name
experiment_name = "Resnet50_MRI_Classification"
mlflow.set_experiment(experiment_name)

# Specify the run ID of the logged model
run_id = "f390913c59d642329c86d0f52b943062"  # Replace with your actual run ID
model_uri = f"runs:/{run_id}/model"

# Load the model
model = mlflow.pytorch.load_model(model_uri)
model.to(torch.device('cuda' if torch.cuda.is_available() else 'cpu'))  # Move model to appropriate device
model.eval()  # Set the model to evaluation mode

# Prepare data
transform = transforms.Compose([
    transforms.ToPILImage(),
    transforms.Resize((224, 224)),
    transforms.ColorJitter(brightness=0.2, contrast=0.2, saturation=0.2, hue=0.1),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
])

class MRIDataset(Dataset):
    def __init__(self, data, transform=None):
        self.data = data
        self.transform = transform
        self.data['severity'] = self.data['severity'].astype(int)

    def __getitem__(self, index):
        row = self.data.iloc[index]
        image_path = row['image_path']
        label = row['severity']
        dicom_image = pydicom.dcmread(image_path)
        image = dicom_image.pixel_array.astype(float)
        image = (image / image.max() * 255).astype('uint8')
        if len(image.shape) == 2:  # Grayscale
            image = cv2.cvtColor(image, cv2.COLOR_GRAY2RGB)
        image_tensor = self.transform(image) if self.transform else torch.from_numpy(image).permute(2, 0, 1)
        return image_tensor, torch.tensor(label).long()

    def __len__(self):
        return len(self.data)

# %% [markdown]
# predicting probabilities for test data

# %%
test_data = random_samples_test_check

test_dataset = MRIDataset(data=test_data, transform=transform)
test_loader = DataLoader(test_dataset, batch_size=1, shuffle=False)

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print(f"Using device: {device}")

# Inference loop with probability extraction
results = []
probabilities_list = []

with torch.no_grad():
    for images, labels in test_loader:
        images = images.to(device)
        labels = labels.to(device)  # Ensure labels are also on the correct device
        outputs = model(images)
        probabilities = torch.softmax(outputs, dim=1)  # Calculate class probabilities
        _, predicted_classes = torch.max(outputs, 1)
        
        # Append predictions and probabilities
        results.append(predicted_classes.item())
        probabilities_list.append(probabilities.cpu().numpy())
# Out:
# Using device: cpu

# %%
# Print predicted classes and their probabilities
for i, (pred, probs) in enumerate(zip(results, probabilities_list)):
    print(f"Test image {i}: Predicted class {pred}, Probabilities: {probs}")

# Additional code to plot the confusion matrix can stay as-is:
true_labels = []
predicted_labels = []

for images, labels in test_loader:
    images = images.to(device)
    true_labels.extend(labels.numpy())

    with torch.no_grad():
        outputs = model(images)
        _, predicted_classes = torch.max(outputs, 1)
        predicted_labels.extend(predicted_classes.cpu().numpy())

true_labels = np.array(true_labels)
predicted_labels = np.array(predicted_labels)

print("True Labels Unique Values:", np.unique(true_labels))
print("Predicted Labels Unique Values:", np.unique(predicted_labels))
# Out:
# Test image 0: Predicted class 2, Probabilities: [[0.15330388 0.37742668 0.46926945]]
# Test image 1: Predicted class 2, Probabilities: [[0.13040946 0.37752903 0.49206153]]
# Test image 2: Predicted class 1, Probabilities: [[0.23696716 0.44675255 0.31628034]]
# Test image 3: Predicted class 0, Probabilities: [[0.44080806 0.22888544 0.33030653]]
# Test image 4: Predicted class 0, Probabilities: [[0.47634664 0.0746745  0.44897893]]
# Test image 5: Predicted class 2, Probabilities: [[0.3311112  0.32648456 0.3424043 ]]
# Test image 6: Predicted class 0, Probabilities: [[0.4435912  0.22052014 0.33588868]]
# Test image 7: Predicted class 2, Probabilities: [[0.14793454 0.2277063  0.6243592 ]]
# Test image 8: Predicted class 2, Probabilities: [[0.09944285 0.4276044  0.4729527 ]]
# Test image 9: Predicted class 1, Probabilities: [[0.11186356 0.544449   0.3436875 ]]
# Test image 10: Predicted class 1, Probabilities: [[0.14050353 0.43831402 0.4211824 ]]
# Test image 11: Predicted class 0, Probabilities: [[0.45977855 0.2755081  0.26471332]]
# Test image 12: Predicted class 2, Probabilities: [[0.29826182 0.23683783 0.46490034]]
# Test image 13: Predicted class 2, Probabilities: [[0.30879673 0.32757536 0.36362788]]
# Test image 14: Predicted class 2, Probabilities: [[0.29964858 0.250822   0.44952935]]
# Test image 15: Predicted class 1, Probabilities: [[0.12582909 0.47911265 0.39505827]]
# Test image 16: Predicted class 2, Probabilities: [[0.20874979 0.26046112 0.5307891 ]]
# Test image 17: Predicted class 1, Probabilities: [[0.2623559  0.46909377 0.26855034]]
# Test image 18: Predicted class 2, Probabilities: [[0.1959549  0.28847304 0.515572  ]]
# Test image 19: Predicted class 0, Probabilities: [[0.506386   0.11432274 0.3792912 ]]
# Test image 20: Predicted class 2, Probabilities: [[0.13669865 0.37761027 0.4856911 ]]
# Test image 21: Predicted class 1, Probabilities: [[0.19665334 0.5299069  0.27343976]]
# Test image 22: Predicted class 2, Probabilities: [[0.10763121 0.24961445 0.6427543 ]]
# Test image 23: Predicted class 2, Probabilities: [[0.24673752 0.19817497 0.5550875 ]]
# Test image 24: Predicted class 2, Probabilities: [[0.03781815 0.11427746 0.8479044 ]]
# Test image 25: Predicted class 2, Probabilities: [[0.20554468 0.3669644  0.427491  ]]
# Test image 26: Predicted class 2, Probabilities: [[0.1303457  0.3846325  0.48502183]]
# Test image 27: Predicted class 2, Probabilities: [[0.23856041 0.24213398 0.51930565]]
# Test image 28: Predicted class 2, Probabilities: [[0.10637494 0.15638645 0.73723865]]
# Test image 29: Predicted class 2, Probabilities: [[0.02589102 0.02346916 0.9506398 ]]
# Test image 30: Predicted class 0, Probabilities: [[0.56102407 0.17831713 0.26065883]]
# Test image 31: Predicted class 0, Probabilities: [[0.40498808 0.24387418 0.35113776]]
# Test image 32: Predicted class 2, Probabilities: [[0.22894295 0.2237372  0.5473199 ]]
# Test image 33: Predicted class 2, Probabilities: [[0.33279628 0.14934434 0.51785934]]
# Test image 34: Predicted class 0, Probabilities: [[0.4377492  0.30168256 0.26056832]]
# Test image 35: Predicted class 2, Probabilities: [[0.18017721 0.22231476 0.5975081 ]]
# Test image 36: Predicted class 2, Probabilities: [[0.15279116 0.36280963 0.48439923]]
# Test image 37: Predicted class 2, Probabilities: [[0.13229342 0.39842933 0.46927726]]
# Test image 38: Predicted class 2, Probabilities: [[0.27070582 0.26202485 0.46726933]]
# Test image 39: Predicted class 1, Probabilities: [[0.08626374 0.53323114 0.38050517]]
# Test image 40: Predicted class 2, Probabilities: [[0.25090644 0.18635014 0.5627434 ]]
# Test image 41: Predicted class 2, Probabilities: [[0.18829344 0.17828111 0.6334255 ]]
# Test image 42: Predicted class 2, Probabilities: [[0.15110302 0.2928192  0.5560777 ]]
# Test image 43: Predicted class 2, Probabilities: [[0.1614     0.33560282 0.50299716]]
# Test image 44: Predicted class 1, Probabilities: [[0.19969304 0.5227972  0.2775097 ]]
# Test image 45: Predicted class 2, Probabilities: [[0.2004915  0.37882537 0.4206832 ]]
# Test image 46: Predicted class 2, Probabilities: [[0.20608823 0.33601406 0.45789766]]
# Test image 47: Predicted class 1, Probabilities: [[0.05722553 0.5554893  0.38728514]]
# Test image 48: Predicted class 0, Probabilities: [[0.3953877  0.33460563 0.27000666]]
# Test image 49: Predicted class 2, Probabilities: [[0.21746081 0.22910951 0.5534297 ]]
# Test image 50: Predicted class 2, Probabilities: [[0.03896886 0.13813688 0.8228943 ]]
# Test image 51: Predicted class 2, Probabilities: [[0.11636749 0.36068207 0.5229505 ]]
# Test image 52: Predicted class 2, Probabilities: [[0.26373497 0.25666592 0.47959912]]
# Test image 53: Predicted class 1, Probabilities: [[0.1376285  0.53164095 0.33073053]]
# Test image 54: Predicted class 2, Probabilities: [[0.1648178  0.37714627 0.45803586]]
# Test image 55: Predicted class 2, Probabilities: [[0.2262914  0.25814867 0.51556   ]]
# Test image 56: Predicted class 1, Probabilities: [[0.12135889 0.5097663  0.36887485]]
# Test image 57: Predicted class 2, Probabilities: [[0.14961952 0.14390394 0.70647657]]
# Test image 58: Predicted class 1, Probabilities: [[0.16690548 0.50551313 0.32758138]]
# Test image 59: Predicted class 2, Probabilities: [[0.22468999 0.3797014  0.39560863]]
# Test image 60: Predicted class 1, Probabilities: [[0.13047983 0.5458814  0.32363877]]
# Test image 61: Predicted class 0, Probabilities: [[0.38717678 0.37115404 0.24166916]]
# Test image 62: Predicted class 2, Probabilities: [[0.37414145 0.25031677 0.3755418 ]]
# Test image 63: Predicted class 2, Probabilities: [[0.30910105 0.27647153 0.4144274 ]]
# Test image 64: Predicted class 2, Probabilities: [[0.15237539 0.26558968 0.5820349 ]]
# Test image 65: Predicted class 2, Probabilities: [[0.24811968 0.3497957  0.4020846 ]]
# Test image 66: Predicted class 2, Probabilities: [[0.22357765 0.2520167  0.52440566]]
# Test image 67: Predicted class 2, Probabilities: [[0.19515906 0.28723213 0.51760876]]
# Test image 68: Predicted class 2, Probabilities: [[0.3568737  0.22792855 0.4151977 ]]
# Test image 69: Predicted class 2, Probabilities: [[0.18476062 0.36367956 0.45155987]]
# Test image 70: Predicted class 2, Probabilities: [[0.23758946 0.36403453 0.39837608]]
# Test image 71: Predicted class 2, Probabilities: [[0.23740435 0.35487804 0.40771765]]
# Test image 72: Predicted class 2, Probabilities: [[0.07988957 0.332663   0.58744746]]
# Test image 73: Predicted class 2, Probabilities: [[0.28207204 0.33181494 0.38611302]]
# Test image 74: Predicted class 2, Probabilities: [[0.22423086 0.32579076 0.44997844]]
# Test image 75: Predicted class 0, Probabilities: [[0.37841156 0.30875453 0.31283394]]
# Test image 76: Predicted class 1, Probabilities: [[0.30627808 0.44050166 0.25322017]]
# Test image 77: Predicted class 2, Probabilities: [[0.08050918 0.4035388  0.51595205]]
# Test image 78: Predicted class 0, Probabilities: [[0.46047127 0.19553474 0.34399405]]
# Test image 79: Predicted class 2, Probabilities: [[0.23463827 0.28502452 0.48033726]]
# Test image 80: Predicted class 2, Probabilities: [[0.08788129 0.27440146 0.63771725]]
# Test image 81: Predicted class 2, Probabilities: [[0.09700553 0.38630855 0.51668596]]
# Test image 82: Predicted class 2, Probabilities: [[0.18708916 0.3901675  0.42274332]]
# Test image 83: Predicted class 2, Probabilities: [[0.32107416 0.24120651 0.43771937]]
# Test image 84: Predicted class 2, Probabilities: [[0.1494199  0.41505352 0.43552658]]
# Test image 85: Predicted class 2, Probabilities: [[0.0849501  0.1951146  0.71993536]]
# Test image 86: Predicted class 0, Probabilities: [[0.4038092  0.2056888  0.39050192]]
# Test image 87: Predicted class 2, Probabilities: [[0.14836292 0.27613962 0.5754975 ]]
# Test image 88: Predicted class 0, Probabilities: [[0.34550506 0.33029628 0.32419866]]
# Test image 89: Predicted class 2, Probabilities: [[0.18426369 0.25540867 0.5603276 ]]
# Test image 90: Predicted class 1, Probabilities: [[0.08783055 0.4662514  0.44591805]]
# Test image 91: Predicted class 2, Probabilities: [[0.1521571  0.3284297  0.51941323]]
# Test image 92: Predicted class 1, Probabilities: [[0.2527116  0.43296364 0.3143249 ]]
# Test image 93: Predicted class 2, Probabilities: [[0.17797026 0.31947604 0.50255376]]
# Test image 94: Predicted class 1, Probabilities: [[0.09079474 0.4810348  0.42817047]]
# Test image 95: Predicted class 2, Probabilities: [[0.32973742 0.32767633 0.34258625]]
# Test image 96: Predicted class 1, Probabilities: [[0.2875507  0.3644386  0.34801078]]
# Test image 97: Predicted class 0, Probabilities: [[0.4112587  0.29130933 0.2974321 ]]
# Test image 98: Predicted class 1, Probabilities: [[0.04808405 0.4771714  0.47474453]]
# Test image 99: Predicted class 1, Probabilities: [[0.22961488 0.39269146 0.37769368]]
# True Labels Unique Values: [0 1 2]
# Predicted Labels Unique Values: [0 1 2]

# %%
from sklearn.metrics import confusion_matrix
import pandas as pd
import numpy as np

# Generate the confusion matrix
conf_matrix = confusion_matrix(true_labels, predicted_labels)

# Create a DataFrame from the confusion matrix
conf_matrix_df = pd.DataFrame(
    conf_matrix, 
    index=[f"Actual {i}" for i in range(len(conf_matrix))], 
    columns=[f"Predicted {i}" for i in range(len(conf_matrix[0]))]
)

# Print the confusion matrix DataFrame
print(conf_matrix_df)

# Optionally, display it using a more formatted view (e.g., in Jupyter Notebook)
conf_matrix_df.style.background_gradient(cmap='Blues')
# Out:
#           Predicted 0  Predicted 1  Predicted 2
# Actual 0            5           11           22
# Actual 1            6            3           22
# Actual 2            2            8           21
# <style type="text/css">
# #T_9c6c2_row0_col0 {
#   background-color: #2070b4;
#   color: #f1f1f1;
# }
# #T_9c6c2_row0_col1, #T_9c6c2_row0_col2, #T_9c6c2_row1_col0, #T_9c6c2_row1_col2 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_9c6c2_row1_col1, #T_9c6c2_row2_col0, #T_9c6c2_row2_col2 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_9c6c2_row2_col1 {
#   background-color: #4191c6;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_9c6c2">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_9c6c2_level0_col0" class="col_heading level0 col0" >Predicted 0</th>
#       <th id="T_9c6c2_level0_col1" class="col_heading level0 col1" >Predicted 1</th>
#       <th id="T_9c6c2_level0_col2" class="col_heading level0 col2" >Predicted 2</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_9c6c2_level0_row0" class="row_heading level0 row0" >Actual 0</th>
#       <td id="T_9c6c2_row0_col0" class="data row0 col0" >5</td>
#       <td id="T_9c6c2_row0_col1" class="data row0 col1" >11</td>
#       <td id="T_9c6c2_row0_col2" class="data row0 col2" >22</td>
#     </tr>
#     <tr>
#       <th id="T_9c6c2_level0_row1" class="row_heading level0 row1" >Actual 1</th>
#       <td id="T_9c6c2_row1_col0" class="data row1 col0" >6</td>
#       <td id="T_9c6c2_row1_col1" class="data row1 col1" >3</td>
#       <td id="T_9c6c2_row1_col2" class="data row1 col2" >22</td>
#     </tr>
#     <tr>
#       <th id="T_9c6c2_level0_row2" class="row_heading level0 row2" >Actual 2</th>
#       <td id="T_9c6c2_row2_col0" class="data row2 col0" >2</td>
#       <td id="T_9c6c2_row2_col1" class="data row2 col1" >8</td>
#       <td id="T_9c6c2_row2_col2" class="data row2 col2" >21</td>
#     </tr>
#   </tbody>
# </table>

# %%
# Convert the list of probabilities to a numpy array for easier manipulation
probabilities_array = np.vstack(probabilities_list)

# Calculate the average probability for each class
average_probabilities = np.mean(probabilities_array, axis=0)

# Print the average probabilities
for i, avg_prob in enumerate(average_probabilities):
    print(f"Average probability for class {i}: {avg_prob:.4f}")
# Out:
# Average probability for class 0: 0.2240
# Average probability for class 1: 0.3211
# Average probability for class 2: 0.4550

# %%
from sklearn.metrics import precision_score, recall_score, accuracy_score
# Calculate precision, recall, and accuracy using mean_probabilities_df
precision = precision_score(true_labels, predicted_labels, average='weighted')
recall = recall_score(true_labels, predicted_labels, average='weighted')
accuracy = accuracy_score(true_labels, predicted_labels)

print(f"Precision: {precision:.4f}")
print(f"Recall: {recall:.4f}")
print(f"Accuracy: {accuracy:.4f}")
# Out:
# Precision: 0.2886
# Recall: 0.2900
# Accuracy: 0.2900
