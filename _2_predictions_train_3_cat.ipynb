# %% [markdown]
# Packages:

# %%
import glob
import os
import warnings
 
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import pydicom
from pydicom.data import get_testdata_files
from sklearn.model_selection import train_test_split

from IPython.display import Markdown, display

 # Import functions from the module
import importlib
import help_files._0_definitions 
import  help_files._1_visuals_script
# import  help_files._01_load_data
 # Reload the module to apply the changes to the script
importlib.reload(help_files._0_definitions)
importlib.reload(help_files._1_visuals_script)
# importlib.reload(help_files._01_load_data)
import  help_files._1_visuals_script  as pauls_vs
# Group by 'condition', 'level', and 'severity' and count occurrences
from help_files._0_definitions import count_severity_by_condition_level 
# Define the path
from pathlib import Path

pd.set_option("display.width", 1000)  # Set a large width to prevent line wrapping

# %%
### In definitions are all the functions that are used in the notebook and globals
with open("help_files/_0_definitions.py") as file:
    exec(file.read())

# %%
 

# Specify the file names and DataFrame variable names
file_names = ["test_df_3_cat.csv"]

# Load the data from the CSV files
dataframes = [pd.read_csv(data_path_vor / file_name) for file_name in file_names]
# Load train_df as a DataFrame
test_df = dataframes[0]
test_df = test_df.sample(frac=0.5, random_state=RSEED)
print("DataFrames have been loaded successfully.")

# %% [markdown]
# Restore parameters and metrtics from mlflow

# %% [markdown]
# I should take prdicted probabilities and not predicted classes: output scores (logits) are converted into probabilities using the softmax function

# %%
import mlflow
import mlflow.pytorch
import torch
from torch import nn, optim
from torch.utils.data import Dataset, DataLoader, random_split
import torchvision.models as models
from torchvision import transforms
import pydicom
import cv2
import pandas as pd
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
import matplotlib.pyplot as plt
import numpy as np

# Set the experiment name
experiment_name = "407167111170960490"
mlflow.set_experiment(experiment_name)

# Specify the run ID of the logged model
run_id = "e2279f9e4abb43f9824a1ba402ce8168"  # Replace with your actual run ID
model_uri = f"runs:/{run_id}/model"

# Load the model
model = mlflow.pytorch.load_model(model_uri)
model.to(torch.device('cuda' if torch.cuda.is_available() else 'cpu'))  # Move model to appropriate device
model.eval()  # Set the model to evaluation mode

# Prepare data
transform = transforms.Compose([
    transforms.ToPILImage(),
    transforms.Resize((224, 224)),
    transforms.ColorJitter(brightness=0.2, contrast=0.2, saturation=0.2, hue=0.1),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
])

class MRIDataset(Dataset):
    def __init__(self, data, transform=None):
        self.data = data
        self.transform = transform
        self.data['severity'] = self.data['severity'].astype(int)

    def __getitem__(self, index):
        row = self.data.iloc[index]
        image_path = row['image_path']
        label = row['severity']
        dicom_image = pydicom.dcmread(image_path)
        image = dicom_image.pixel_array.astype(float)
        image = (image / image.max() * 255).astype('uint8')
        if len(image.shape) == 2:  # Grayscale
            image = cv2.cvtColor(image, cv2.COLOR_GRAY2RGB)
        image_tensor = self.transform(image) if self.transform else torch.from_numpy(image).permute(2, 0, 1)
        return image_tensor, torch.tensor(label).long()

    def __len__(self):
        return len(self.data)

# %% [markdown]
# predicting probabilities for test data

# %%
test_data = test_df

# %%
test_dataset = MRIDataset(data=test_data, transform=transform)
test_loader = DataLoader(test_dataset, batch_size=1, shuffle=False)

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print(f"Using device: {device}")

# Inference loop with probability extraction
results = []
probabilities_list = []

with torch.no_grad():
    for images, labels in test_loader:
        images = images.to(device)
        labels = labels.to(device)  # Ensure labels are also on the correct device
        outputs = model(images)
        probabilities = torch.softmax(outputs, dim=1)  # Calculate class probabilities
        _, predicted_classes = torch.max(outputs, 1)
        
        # Append predictions and probabilities
        results.append(predicted_classes.item())
        probabilities_list.append(probabilities.cpu().numpy())

# %%
# Print predicted classes and their probabilities
for i, (pred, probs) in enumerate(zip(results, probabilities_list)):
    print(f"Test image {i}: Predicted class {pred}, Probabilities: {probs}")

# Additional code to plot the confusion matrix can stay as-is:
true_labels = []
predicted_labels = []

for images, labels in test_loader:
    images = images.to(device)
    true_labels.extend(labels.numpy())

    with torch.no_grad():
        outputs = model(images)
        _, predicted_classes = torch.max(outputs, 1)
        predicted_labels.extend(predicted_classes.cpu().numpy())

true_labels = np.array(true_labels)
predicted_labels = np.array(predicted_labels)

print("True Labels Unique Values:", np.unique(true_labels))
print("Predicted Labels Unique Values:", np.unique(predicted_labels))
# Out:
# Test image 0: Predicted class 1, Probabilities: [[0.00468007 0.67013323 0.3251867 ]]
# Test image 1: Predicted class 2, Probabilities: [[1.59805131e-04 1.53880585e-02 9.84452128e-01]]
# Test image 2: Predicted class 1, Probabilities: [[8.4838719e-04 9.9664080e-01 2.5107723e-03]]
# Test image 3: Predicted class 0, Probabilities: [[0.9588287  0.0389594  0.00221194]]
# Test image 4: Predicted class 1, Probabilities: [[0.447508   0.5506946  0.00179744]]
# Test image 5: Predicted class 0, Probabilities: [[9.7433633e-01 2.5502523e-02 1.6115354e-04]]
# Test image 6: Predicted class 1, Probabilities: [[1.3570620e-03 9.9864095e-01 1.9822594e-06]]
# Test image 7: Predicted class 0, Probabilities: [[0.8226465  0.1762069  0.00114661]]
# Test image 8: Predicted class 1, Probabilities: [[3.6824416e-04 9.9912840e-01 5.0338294e-04]]
# Test image 9: Predicted class 1, Probabilities: [[7.9903041e-04 9.9778086e-01 1.4200711e-03]]
# Test image 10: Predicted class 0, Probabilities: [[9.908626e-01 9.045723e-03 9.168630e-05]]
# Test image 11: Predicted class 1, Probabilities: [[3.5208657e-05 9.9994528e-01 1.9562327e-05]]
# Test image 12: Predicted class 2, Probabilities: [[1.2409149e-06 4.0091737e-04 9.9959785e-01]]
# Test image 13: Predicted class 2, Probabilities: [[2.7843325e-07 7.2523949e-06 9.9999249e-01]]
# Test image 14: Predicted class 1, Probabilities: [[7.171455e-03 9.927618e-01 6.677748e-05]]
# Test image 15: Predicted class 2, Probabilities: [[0.00344386 0.45461404 0.5419421 ]]
# Test image 16: Predicted class 0, Probabilities: [[0.68501467 0.28330064 0.03168467]]
# Test image 17: Predicted class 0, Probabilities: [[0.8441299  0.15458989 0.00128017]]
# Test image 18: Predicted class 2, Probabilities: [[6.7883789e-06 1.7200572e-03 9.9827313e-01]]
# Test image 19: Predicted class 1, Probabilities: [[3.8168253e-03 9.9610919e-01 7.3956937e-05]]
# Test image 20: Predicted class 2, Probabilities: [[0.00242724 0.00473921 0.9928335 ]]
# Test image 21: Predicted class 1, Probabilities: [[0.00181309 0.98966855 0.00851831]]
# Test image 22: Predicted class 0, Probabilities: [[0.9804002  0.01781719 0.00178266]]
# Test image 23: Predicted class 2, Probabilities: [[4.2991360e-06 2.1774437e-04 9.9977797e-01]]
# Test image 24: Predicted class 2, Probabilities: [[0.32446468 0.2528677  0.42266762]]
# Test image 25: Predicted class 2, Probabilities: [[0.02188217 0.01936479 0.95875305]]
# Test image 26: Predicted class 1, Probabilities: [[3.1161590e-03 9.9675542e-01 1.2848194e-04]]
# Test image 27: Predicted class 2, Probabilities: [[0.00677937 0.02305115 0.9701694 ]]
# Test image 28: Predicted class 1, Probabilities: [[6.6396379e-04 8.2981193e-01 1.6952412e-01]]
# Test image 29: Predicted class 0, Probabilities: [[6.2260514e-01 3.7723264e-01 1.6221184e-04]]
# Test image 30: Predicted class 1, Probabilities: [[4.0723957e-04 9.9656266e-01 3.0300976e-03]]
# Test image 31: Predicted class 2, Probabilities: [[0.00301101 0.03124672 0.96574223]]
# Test image 32: Predicted class 0, Probabilities: [[0.5936165  0.401735   0.00464849]]
# Test image 33: Predicted class 1, Probabilities: [[4.6820901e-03 9.9514633e-01 1.7154751e-04]]
# Test image 34: Predicted class 1, Probabilities: [[5.4268586e-03 9.9426681e-01 3.0639328e-04]]
# Test image 35: Predicted class 2, Probabilities: [[6.4877945e-04 9.7098044e-04 9.9838018e-01]]
# Test image 36: Predicted class 2, Probabilities: [[5.4723714e-05 2.4399490e-03 9.9750537e-01]]
# Test image 37: Predicted class 0, Probabilities: [[0.646901   0.33158183 0.02151716]]
# Test image 38: Predicted class 2, Probabilities: [[1.7680043e-04 1.4634164e-01 8.5348153e-01]]
# Test image 39: Predicted class 1, Probabilities: [[6.6896610e-02 9.3244481e-01 6.5857614e-04]]
# Test image 40: Predicted class 2, Probabilities: [[0.05679548 0.01975605 0.9234485 ]]
# Test image 41: Predicted class 1, Probabilities: [[2.8186309e-01 7.1794373e-01 1.9320988e-04]]
# Test image 42: Predicted class 0, Probabilities: [[9.3058628e-01 6.9282204e-02 1.3156488e-04]]
# Test image 43: Predicted class 1, Probabilities: [[3.5551780e-01 6.4385766e-01 6.2458194e-04]]
# Test image 44: Predicted class 2, Probabilities: [[8.5233150e-06 2.0574275e-03 9.9793410e-01]]
# Test image 45: Predicted class 0, Probabilities: [[0.7831869  0.19195275 0.02486025]]
# Test image 46: Predicted class 0, Probabilities: [[0.96104985 0.00261263 0.03633745]]
# Test image 47: Predicted class 2, Probabilities: [[1.43427715e-05 2.80115084e-04 9.99705493e-01]]
# Test image 48: Predicted class 0, Probabilities: [[9.8737526e-01 1.2612034e-02 1.2697186e-05]]
# Test image 49: Predicted class 0, Probabilities: [[0.97783786 0.01451221 0.00765002]]
# Test image 50: Predicted class 0, Probabilities: [[0.9265076  0.07203604 0.00145639]]
# Test image 51: Predicted class 1, Probabilities: [[4.8668042e-01 5.1307428e-01 2.4532742e-04]]
# Test image 52: Predicted class 0, Probabilities: [[6.6434324e-01 3.3549008e-01 1.6673020e-04]]
# Test image 53: Predicted class 1, Probabilities: [[1.8548442e-04 6.8036038e-01 3.1945416e-01]]
# Test image 54: Predicted class 2, Probabilities: [[4.9335306e-04 5.6332615e-03 9.9387336e-01]]
# Test image 55: Predicted class 1, Probabilities: [[3.1108364e-01 6.8856478e-01 3.5152666e-04]]
# Test image 56: Predicted class 0, Probabilities: [[0.6734587  0.32472402 0.00181729]]
# Test image 57: Predicted class 0, Probabilities: [[9.7670597e-01 2.2459619e-02 8.3441637e-04]]
# Test image 58: Predicted class 2, Probabilities: [[0.43176645 0.00337792 0.56485564]]
# Test image 59: Predicted class 0, Probabilities: [[9.9210232e-01 7.5317617e-03 3.6587889e-04]]
# Test image 60: Predicted class 2, Probabilities: [[0.0009693  0.03444384 0.9645869 ]]
# Test image 61: Predicted class 0, Probabilities: [[0.9200223  0.06638597 0.01359174]]
# Test image 62: Predicted class 2, Probabilities: [[1.7006756e-04 2.9712729e-03 9.9685860e-01]]
# Test image 63: Predicted class 1, Probabilities: [[0.00447785 0.7049613  0.2905608 ]]
# Test image 194: Predicted class 2, Probabilities: [[1.4393504e-05 8.6835828e-03 9.9130201e-01]]
# Test image 195: Predicted class 1, Probabilities: [[3.6117829e-02 9.6379215e-01 8.9976937e-05]]
# Test image 196: Predicted class 2, Probabilities: [[4.834030e-06 5.034675e-04 9.994917e-01]]
# Test image 197: Predicted class 0, Probabilities: [[7.1221262e-01 2.8751254e-01 2.7489773e-04]]
# Test image 198: Predicted class 1, Probabilities: [[2.7239986e-04 9.9972552e-01 2.0052357e-06]]
# Test image 199: Predicted class 1, Probabilities: [[0.43519506 0.54512733 0.01967762]]
# Test image 200: Predicted class 0, Probabilities: [[8.7488472e-01 1.2504622e-01 6.9043141e-05]]
# Test image 201: Predicted class 1, Probabilities: [[3.32904100e-01 6.67081058e-01 1.47557475e-05]]
# Test image 202: Predicted class 2, Probabilities: [[5.1502630e-05 8.9428195e-04 9.9905425e-01]]
# Test image 203: Predicted class 0, Probabilities: [[0.99100643 0.0059074  0.00308607]]
# Test image 204: Predicted class 0, Probabilities: [[0.9607182  0.03469891 0.00458286]]
# Test image 205: Predicted class 1, Probabilities: [[0.12318546 0.7819895  0.09482498]]
# Test image 206: Predicted class 0, Probabilities: [[9.8281473e-01 1.6915223e-02 2.7010537e-04]]
# Test image 207: Predicted class 2, Probabilities: [[2.3077329e-05 1.5999872e-03 9.9837697e-01]]
# Test image 208: Predicted class 1, Probabilities: [[4.1497545e-04 9.9956173e-01 2.3258763e-05]]
# Test image 209: Predicted class 2, Probabilities: [[7.0691553e-05 3.0774088e-03 9.9685186e-01]]
# Test image 210: Predicted class 0, Probabilities: [[9.1768748e-01 8.2212225e-02 1.0034246e-04]]
# Test image 211: Predicted class 0, Probabilities: [[0.98313403 0.01511367 0.00175224]]
# Test image 212: Predicted class 0, Probabilities: [[0.97955304 0.01941717 0.00102981]]
# Test image 213: Predicted class 1, Probabilities: [[1.8497223e-02 9.8108000e-01 4.2280977e-04]]
# Test image 214: Predicted class 1, Probabilities: [[1.19393626e-04 9.99828458e-01 5.20362919e-05]]
# Test image 215: Predicted class 1, Probabilities: [[3.7237544e-02 9.6254504e-01 2.1739517e-04]]
# Test image 216: Predicted class 1, Probabilities: [[4.2948104e-02 9.5686918e-01 1.8278902e-04]]
# Test image 217: Predicted class 0, Probabilities: [[0.9889101  0.00989566 0.0011942 ]]
# Test image 218: Predicted class 0, Probabilities: [[0.6417861  0.35734907 0.00086486]]
# Test image 219: Predicted class 2, Probabilities: [[1.1854929e-04 3.2191114e-03 9.9666238e-01]]
# Test image 220: Predicted class 0, Probabilities: [[0.959115   0.03992569 0.00095924]]
# Test image 221: Predicted class 2, Probabilities: [[0.06635059 0.32130057 0.6123489 ]]
# Test image 222: Predicted class 1, Probabilities: [[0.35459664 0.6440945  0.00130883]]
# Test image 223: Predicted class 1, Probabilities: [[0.10737249 0.88299835 0.00962916]]
# Test image 224: Predicted class 0, Probabilities: [[9.4180644e-01 5.8190167e-02 3.3794122e-06]]
# Test image 225: Predicted class 2, Probabilities: [[9.3756197e-04 3.2708138e-02 9.6635437e-01]]
# Test image 487: Predicted class 0, Probabilities: [[0.96948886 0.02564371 0.00486744]]
# Test image 488: Predicted class 1, Probabilities: [[0.00366343 0.9952018  0.00113472]]
# Test image 489: Predicted class 2, Probabilities: [[5.4267542e-07 4.1364244e-04 9.9958581e-01]]
# Test image 490: Predicted class 1, Probabilities: [[3.2248661e-02 9.6688384e-01 8.6743128e-04]]
# Test image 491: Predicted class 1, Probabilities: [[0.00240223 0.9925177  0.00508009]]
# Test image 492: Predicted class 0, Probabilities: [[0.90163964 0.09275163 0.0056087 ]]
# Test image 493: Predicted class 0, Probabilities: [[0.754334   0.24477687 0.0008892 ]]
# Test image 494: Predicted class 1, Probabilities: [[1.7994212e-03 9.9771321e-01 4.8738378e-04]]
# Test image 495: Predicted class 1, Probabilities: [[0.01377168 0.9840613  0.00216704]]
# Test image 496: Predicted class 0, Probabilities: [[9.995654e-01 3.602712e-04 7.436935e-05]]
# Test image 497: Predicted class 1, Probabilities: [[2.7833227e-03 9.9705374e-01 1.6298082e-04]]
# Test image 498: Predicted class 1, Probabilities: [[5.1458988e-02 9.4800007e-01 5.4101273e-04]]
# Test image 499: Predicted class 2, Probabilities: [[1.0421899e-04 4.7002317e-04 9.9942577e-01]]
# Test image 500: Predicted class 0, Probabilities: [[0.5045069  0.48781398 0.00767912]]
# Test image 501: Predicted class 1, Probabilities: [[6.4990825e-05 9.9560225e-01 4.3327301e-03]]
# Test image 502: Predicted class 1, Probabilities: [[0.03974165 0.95251566 0.00774274]]
# Test image 503: Predicted class 1, Probabilities: [[0.0010352  0.9617121  0.03725266]]
# Test image 504: Predicted class 0, Probabilities: [[9.014293e-01 9.848720e-02 8.347614e-05]]
# Test image 505: Predicted class 1, Probabilities: [[0.0018973  0.9931076  0.00499516]]
# Test image 506: Predicted class 2, Probabilities: [[3.4794232e-06 5.5262470e-03 9.9447024e-01]]
# Test image 507: Predicted class 2, Probabilities: [[7.576611e-07 7.613007e-05 9.999231e-01]]
# Test image 508: Predicted class 2, Probabilities: [[1.6655916e-06 1.0502381e-04 9.9989331e-01]]
# Test image 509: Predicted class 1, Probabilities: [[0.04080091 0.95713276 0.00206629]]
# Test image 510: Predicted class 1, Probabilities: [[6.1250787e-04 9.9938643e-01 1.0617968e-06]]
# Test image 511: Predicted class 2, Probabilities: [[2.3201499e-06 4.8016661e-04 9.9951756e-01]]
# Test image 512: Predicted class 0, Probabilities: [[9.931270e-01 5.809214e-04 6.292089e-03]]
# Test image 513: Predicted class 1, Probabilities: [[2.7678901e-04 9.9972159e-01 1.5274753e-06]]
# Test image 514: Predicted class 0, Probabilities: [[0.6115257  0.3768121  0.01166222]]
# Test image 515: Predicted class 0, Probabilities: [[7.7405763e-01 2.2560954e-01 3.3281467e-04]]
# Test image 516: Predicted class 2, Probabilities: [[1.9099762e-06 3.6242403e-05 9.9996185e-01]]
# Test image 517: Predicted class 2, Probabilities: [[4.9497294e-07 9.1106558e-06 9.9999034e-01]]
# Test image 518: Predicted class 2, Probabilities: [[3.69259737e-07 1.28909205e-05 9.99986768e-01]]
# Test image 4708: Predicted class 1, Probabilities: [[6.3115120e-04 9.9933511e-01 3.3753506e-05]]
# Test image 4709: Predicted class 1, Probabilities: [[0.00666623 0.95102423 0.04230952]]
# Test image 4710: Predicted class 0, Probabilities: [[9.4297475e-01 5.6973543e-02 5.1710085e-05]]
# Test image 4711: Predicted class 0, Probabilities: [[0.80760306 0.19153307 0.00086389]]
# Test image 4712: Predicted class 0, Probabilities: [[0.75053847 0.24489233 0.00456921]]
# Test image 4713: Predicted class 1, Probabilities: [[3.1559337e-03 9.9669445e-01 1.4955876e-04]]
# Test image 4714: Predicted class 2, Probabilities: [[6.4756673e-06 2.8114175e-04 9.9971241e-01]]
# Test image 4715: Predicted class 2, Probabilities: [[1.4838637e-06 1.1956122e-04 9.9987888e-01]]
# Test image 4716: Predicted class 1, Probabilities: [[0.313805   0.65162104 0.03457395]]
# Test image 4717: Predicted class 2, Probabilities: [[4.7484926e-05 2.5581717e-04 9.9969673e-01]]
# Test image 4718: Predicted class 0, Probabilities: [[0.7040349  0.29406095 0.00190403]]
# Test image 4719: Predicted class 2, Probabilities: [[1.8238981e-07 1.2479574e-05 9.9998736e-01]]
# Test image 4720: Predicted class 1, Probabilities: [[0.00187278 0.9967727  0.00135452]]
# Test image 4721: Predicted class 2, Probabilities: [[0.02035664 0.24841262 0.7312308 ]]
# Test image 4722: Predicted class 2, Probabilities: [[3.1061880e-03 7.8562467e-04 9.9610823e-01]]
# Test image 4723: Predicted class 0, Probabilities: [[9.9905759e-01 8.9432590e-04 4.8066682e-05]]
# Test image 4724: Predicted class 0, Probabilities: [[9.8481661e-01 1.4703266e-02 4.8006125e-04]]
# Test image 4725: Predicted class 0, Probabilities: [[0.7416005  0.23750369 0.02089581]]
# Test image 4726: Predicted class 0, Probabilities: [[0.96568185 0.02201897 0.01229909]]
# Test image 4727: Predicted class 1, Probabilities: [[1.2925818e-03 9.9864703e-01 6.0298386e-05]]
# Test image 4728: Predicted class 1, Probabilities: [[0.02252175 0.96280235 0.01467597]]
# Test image 4729: Predicted class 2, Probabilities: [[9.0065456e-05 4.4647800e-03 9.9544513e-01]]
# Test image 4730: Predicted class 1, Probabilities: [[1.9967342e-03 9.9781704e-01 1.8624791e-04]]
# Test image 4731: Predicted class 2, Probabilities: [[1.0055665e-04 3.6470930e-03 9.9625236e-01]]
# Test image 4732: Predicted class 2, Probabilities: [[4.5272995e-07 2.1225889e-05 9.9997830e-01]]
# Test image 4733: Predicted class 2, Probabilities: [[8.0833466e-05 8.0089038e-04 9.9911827e-01]]
# Test image 4734: Predicted class 2, Probabilities: [[6.8145869e-07 1.0727883e-03 9.9892646e-01]]
# Test image 4735: Predicted class 1, Probabilities: [[0.00161624 0.85952216 0.1388616 ]]
# Test image 4736: Predicted class 2, Probabilities: [[6.1788911e-04 3.9587505e-03 9.9542338e-01]]
# Test image 4737: Predicted class 0, Probabilities: [[0.88618445 0.10702553 0.00678997]]
# Test image 4738: Predicted class 2, Probabilities: [[2.1907314e-05 1.3665031e-03 9.9861157e-01]]
# Test image 4739: Predicted class 0, Probabilities: [[8.6835587e-01 1.3121831e-01 4.2581139e-04]]
# Test image 4740: Predicted class 1, Probabilities: [[0.01402545 0.9732912  0.01268334]]
# Test image 4741: Predicted class 0, Probabilities: [[9.4356447e-01 5.6147851e-02 2.8771997e-04]]
# Test image 4742: Predicted class 2, Probabilities: [[1.0825318e-04 1.0174699e-03 9.9887425e-01]]
# Test image 4743: Predicted class 2, Probabilities: [[1.5077421e-06 7.4367024e-05 9.9992406e-01]]
# Test image 4744: Predicted class 0, Probabilities: [[8.3048791e-01 1.6871372e-01 7.9831708e-04]]
# Test image 4745: Predicted class 1, Probabilities: [[2.7258128e-02 9.7241062e-01 3.3127682e-04]]
# Test image 4746: Predicted class 1, Probabilities: [[0.05252181 0.94145024 0.00602798]]
# Test image 4747: Predicted class 2, Probabilities: [[3.5628505e-05 6.1438368e-03 9.9382061e-01]]
# Test image 4748: Predicted class 1, Probabilities: [[8.1631597e-03 9.9175960e-01 7.7234254e-05]]
# Test image 4749: Predicted class 1, Probabilities: [[4.8428881e-03 9.9515522e-01 1.8389611e-06]]
# Test image 4750: Predicted class 0, Probabilities: [[9.9034321e-01 9.6278889e-03 2.8892453e-05]]
# Test image 4751: Predicted class 2, Probabilities: [[7.5780452e-05 4.6169963e-03 9.9530727e-01]]
# Test image 4752: Predicted class 2, Probabilities: [[0.14946748 0.02464682 0.8258857 ]]
# Test image 4753: Predicted class 1, Probabilities: [[0.00281594 0.9932191  0.00396496]]
# Test image 4754: Predicted class 1, Probabilities: [[0.00175196 0.853      0.14524816]]
# Test image 4755: Predicted class 1, Probabilities: [[7.0172613e-03 9.9280554e-01 1.7713799e-04]]
# Test image 4756: Predicted class 1, Probabilities: [[3.3583147e-03 9.9655247e-01 8.9165849e-05]]
# Test image 4757: Predicted class 2, Probabilities: [[0.01814289 0.48462954 0.49722758]]
# Test image 4758: Predicted class 1, Probabilities: [[3.966645e-03 9.959785e-01 5.490813e-05]]
# Test image 4759: Predicted class 1, Probabilities: [[0.09057945 0.8960728  0.01334777]]
# Test image 4760: Predicted class 2, Probabilities: [[2.6487428e-04 1.0050916e-03 9.9873000e-01]]
# Test image 4761: Predicted class 1, Probabilities: [[0.24704985 0.7515602  0.00138984]]
# Test image 4762: Predicted class 0, Probabilities: [[9.8757929e-01 1.2342586e-02 7.8200195e-05]]
# Test image 4763: Predicted class 2, Probabilities: [[8.6725064e-05 1.5109313e-03 9.9840230e-01]]
# Test image 4764: Predicted class 1, Probabilities: [[1.4788471e-03 9.9804580e-01 4.7529530e-04]]
# Test image 4765: Predicted class 0, Probabilities: [[0.60365903 0.3687966  0.02754446]]
# Test image 4766: Predicted class 1, Probabilities: [[0.0019306  0.99281985 0.00524962]]
# Test image 4767: Predicted class 0, Probabilities: [[0.8018041  0.18213958 0.01605633]]
# Test image 4768: Predicted class 0, Probabilities: [[0.9272978  0.02201519 0.05068703]]
# Test image 4769: Predicted class 2, Probabilities: [[3.2996066e-04 5.4890096e-02 9.4477999e-01]]
# Test image 4770: Predicted class 0, Probabilities: [[0.75183016 0.24688499 0.00128484]]
# Test image 4771: Predicted class 0, Probabilities: [[9.6712428e-01 3.2471582e-02 4.0404667e-04]]
# Test image 4772: Predicted class 1, Probabilities: [[9.3913270e-04 9.9903119e-01 2.9600835e-05]]
# Test image 4773: Predicted class 2, Probabilities: [[1.0611868e-05 1.2518459e-03 9.9873751e-01]]
# Test image 4774: Predicted class 0, Probabilities: [[6.2062132e-01 3.7897423e-01 4.0439863e-04]]
# Test image 4775: Predicted class 1, Probabilities: [[4.6178196e-03 9.9526167e-01 1.2045640e-04]]
# Test image 4776: Predicted class 0, Probabilities: [[9.9666315e-01 2.8637589e-03 4.7312470e-04]]
# Test image 4777: Predicted class 1, Probabilities: [[0.0013178  0.98294544 0.01573672]]
# Test image 4778: Predicted class 2, Probabilities: [[7.8556423e-07 2.5747848e-05 9.9997342e-01]]
# Test image 4779: Predicted class 2, Probabilities: [[2.5734624e-05 7.9660931e-05 9.9989462e-01]]
# Test image 4780: Predicted class 2, Probabilities: [[1.7756920e-06 1.8654999e-03 9.9813277e-01]]
# Test image 4781: Predicted class 1, Probabilities: [[2.5949955e-02 9.7403258e-01 1.7583328e-05]]
# Test image 4782: Predicted class 1, Probabilities: [[5.0009921e-04 9.9651390e-01 2.9859543e-03]]
# Test image 4783: Predicted class 2, Probabilities: [[1.0576682e-06 4.3442193e-05 9.9995553e-01]]
# Test image 4784: Predicted class 1, Probabilities: [[1.003677e-02 9.899128e-01 5.048795e-05]]
# Test image 4785: Predicted class 1, Probabilities: [[3.2383392e-03 9.9589044e-01 8.7124394e-04]]
# True Labels Unique Values: [0 1 2]
# Predicted Labels Unique Values: [0 1 2]

# %%
# Convert the list of probabilities to a numpy array for easier manipulation
probabilities_array = np.vstack(probabilities_list)

# Ensure the length of probabilities_array matches the length of test_df
probabilities_array = probabilities_array[:len(test_df)]

# Add the probabilities to the test_df DataFrame
test_df['Probability_Class_0'] = probabilities_array[:, 0]
test_df['Probability_Class_1'] = probabilities_array[:, 1]
test_df['Probability_Class_2'] = probabilities_array[:, 2]

# Round the probabilities to 4 decimal places
test_df['Probability_Class_0'] = test_df['Probability_Class_0'].round(4)
test_df['Probability_Class_1'] = test_df['Probability_Class_1'].round(4)
test_df['Probability_Class_2'] = test_df['Probability_Class_2'].round(4)
# Add the predicted classes to the test_df DataFrame
test_df['Predicted_Class'] = results



# Display the updated DataFrame
 
test_df.head()
# Out:
#         study_id  severity  condition  level     series_id           x           y                                         image_path  missing_image  Probability_Class_0  Probability_Class_1  Probability_Class_2  Predicted_Class
# 6296  2775207739         1          0  l5/s1  3.249541e+09  157.538462  250.197802  data/train_images_origin/2775207739/3249541180...          False               0.0047               0.6701               0.3252                1
# 1496   664153360         2          0  l5/s1  1.076246e+09  260.194392  306.003738  data/train_images_origin/664153360/1076245514/...          False               0.0002               0.0154               0.9845                2
# 5040  2273432465         1          0  l5/s1  1.257235e+09  234.036660  287.804481  data/train_images_origin/2273432465/114306451/...          False               0.0008               0.9966               0.0025                1
# 8486  3777149998         0          0  l5/s1  7.355834e+08  151.528158  190.928463  data/train_images_origin/3777149998/3550597941...          False               0.9588               0.0390               0.0022                0
# 8959  3967802493         0          0  l5/s1  1.589249e+09  265.649924  385.753425  data/train_images_origin/3967802493/2054070341...          False               0.4475               0.5507               0.0018                1

# %%
# Group by severity and sum the Probability_Class_1
severity_prob_sum_all_classes = test_df.groupby('severity')[['Probability_Class_0', 'Probability_Class_1', 'Probability_Class_2']].mean()

# Print the result
severity_prob_sum_all_classes
# Use severity_prob_sum_all_classes as confusion matrix
conf_matrix_prob_df = severity_prob_sum_all_classes 
# Create a confusion matrix from severity and predicted class
conf_matrix_severity_pred = confusion_matrix(test_df['severity'], test_df['Predicted_Class'])

# Create a DataFrame from the confusion matrix
conf_matrix_severity_pred_df = pd.DataFrame(
    conf_matrix_severity_pred, 
    index=[f"Actual {i}" for i in range(len(conf_matrix_severity_pred))], 
    columns=[f"Predicted {i}" for i in range(len(conf_matrix_severity_pred[0]))]
)

# Print the confusion matrix DataFrame
print(conf_matrix_severity_pred_df)

# Optionally, display it using a more formatted view (e.g., in Jupyter Notebook)
conf_matrix_severity_pred_df.style.background_gradient(cmap='Blues')
# Print the confusion matrix DataFrame
print(conf_matrix_prob_df)

# Optionally, display it using a more formatted view (e.g., in Jupyter Notebook)
conf_matrix_prob_df.style.background_gradient(cmap='Blues')
# Out:
#           Predicted 0  Predicted 1  Predicted 2
# Actual 0         1282          280           12
# Actual 1           29         1594           14
# Actual 2           12           83         1480
#           Probability_Class_0  Probability_Class_1  Probability_Class_2
# severity
# 0                    0.754056             0.230405             0.015539
# 1                    0.034404             0.947798             0.017795
# 2                    0.015796             0.077630             0.906572
# <style type="text/css">
# #T_f11a0_row0_col0, #T_f11a0_row1_col1, #T_f11a0_row2_col2 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_f11a0_row0_col1 {
#   background-color: #d5e5f4;
#   color: #000000;
# }
# #T_f11a0_row0_col2, #T_f11a0_row1_col2, #T_f11a0_row2_col0, #T_f11a0_row2_col1 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_f11a0_row1_col0 {
#   background-color: #f2f8fd;
#   color: #000000;
# }
# </style>
# <table id="T_f11a0">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_f11a0_level0_col0" class="col_heading level0 col0" >Probability_Class_0</th>
#       <th id="T_f11a0_level0_col1" class="col_heading level0 col1" >Probability_Class_1</th>
#       <th id="T_f11a0_level0_col2" class="col_heading level0 col2" >Probability_Class_2</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >severity</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_f11a0_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_f11a0_row0_col0" class="data row0 col0" >0.754056</td>
#       <td id="T_f11a0_row0_col1" class="data row0 col1" >0.230405</td>
#       <td id="T_f11a0_row0_col2" class="data row0 col2" >0.015539</td>
#     </tr>
#     <tr>
#       <th id="T_f11a0_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_f11a0_row1_col0" class="data row1 col0" >0.034404</td>
#       <td id="T_f11a0_row1_col1" class="data row1 col1" >0.947798</td>
#       <td id="T_f11a0_row1_col2" class="data row1 col2" >0.017795</td>
#     </tr>
#     <tr>
#       <th id="T_f11a0_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_f11a0_row2_col0" class="data row2 col0" >0.015796</td>
#       <td id="T_f11a0_row2_col1" class="data row2 col1" >0.077630</td>
#       <td id="T_f11a0_row2_col2" class="data row2 col2" >0.906572</td>
#     </tr>
#   </tbody>
# </table>

# %%
conf_matrix_severity_pred_df.style.background_gradient(cmap='Blues')
# Out:
# <style type="text/css">
# #T_2aaa6_row0_col0, #T_2aaa6_row1_col1, #T_2aaa6_row2_col2 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_2aaa6_row0_col1 {
#   background-color: #ddeaf7;
#   color: #000000;
# }
# #T_2aaa6_row0_col2, #T_2aaa6_row1_col2, #T_2aaa6_row2_col0, #T_2aaa6_row2_col1 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_2aaa6_row1_col0 {
#   background-color: #f5f9fe;
#   color: #000000;
# }
# </style>
# <table id="T_2aaa6">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_2aaa6_level0_col0" class="col_heading level0 col0" >Predicted 0</th>
#       <th id="T_2aaa6_level0_col1" class="col_heading level0 col1" >Predicted 1</th>
#       <th id="T_2aaa6_level0_col2" class="col_heading level0 col2" >Predicted 2</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_2aaa6_level0_row0" class="row_heading level0 row0" >Actual 0</th>
#       <td id="T_2aaa6_row0_col0" class="data row0 col0" >1282</td>
#       <td id="T_2aaa6_row0_col1" class="data row0 col1" >280</td>
#       <td id="T_2aaa6_row0_col2" class="data row0 col2" >12</td>
#     </tr>
#     <tr>
#       <th id="T_2aaa6_level0_row1" class="row_heading level0 row1" >Actual 1</th>
#       <td id="T_2aaa6_row1_col0" class="data row1 col0" >29</td>
#       <td id="T_2aaa6_row1_col1" class="data row1 col1" >1594</td>
#       <td id="T_2aaa6_row1_col2" class="data row1 col2" >14</td>
#     </tr>
#     <tr>
#       <th id="T_2aaa6_level0_row2" class="row_heading level0 row2" >Actual 2</th>
#       <td id="T_2aaa6_row2_col0" class="data row2 col0" >12</td>
#       <td id="T_2aaa6_row2_col1" class="data row2 col1" >83</td>
#       <td id="T_2aaa6_row2_col2" class="data row2 col2" >1480</td>
#     </tr>
#   </tbody>
# </table>

# %%
from sklearn.metrics import confusion_matrix
import pandas as pd
import numpy as np

# Ensure true_labels and predicted_labels have the same length
min_length = min(len(true_labels), len(predicted_labels))
true_labels = true_labels[:min_length]
predicted_labels = predicted_labels[:min_length]

# Generate the confusion matrix
conf_matrix = confusion_matrix(true_labels, predicted_labels)

# Create a DataFrame from the confusion matrix
conf_matrix_df = pd.DataFrame(
    conf_matrix, 
    index=[f"Actual {i}" for i in range(len(conf_matrix))], 
    columns=[f"Predicted {i}" for i in range(len(conf_matrix[0]))]
)

# Print the confusion matrix DataFrame
print(conf_matrix_df)

# Optionally, display it using a more formatted view (e.g., in Jupyter Notebook)
conf_matrix_df.style.background_gradient(cmap='Blues')
# Out:
#           Predicted 0  Predicted 1  Predicted 2
# Actual 0         1286          275           13
# Actual 1           28         1595           14
# Actual 2           15           93         1467
# <style type="text/css">
# #T_dd1d4_row0_col0, #T_dd1d4_row1_col1, #T_dd1d4_row2_col2 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_dd1d4_row0_col1 {
#   background-color: #dfebf7;
#   color: #000000;
# }
# #T_dd1d4_row0_col2, #T_dd1d4_row1_col2, #T_dd1d4_row2_col0, #T_dd1d4_row2_col1 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_dd1d4_row1_col0 {
#   background-color: #f5fafe;
#   color: #000000;
# }
# </style>
# <table id="T_dd1d4">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_dd1d4_level0_col0" class="col_heading level0 col0" >Predicted 0</th>
#       <th id="T_dd1d4_level0_col1" class="col_heading level0 col1" >Predicted 1</th>
#       <th id="T_dd1d4_level0_col2" class="col_heading level0 col2" >Predicted 2</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_dd1d4_level0_row0" class="row_heading level0 row0" >Actual 0</th>
#       <td id="T_dd1d4_row0_col0" class="data row0 col0" >1286</td>
#       <td id="T_dd1d4_row0_col1" class="data row0 col1" >275</td>
#       <td id="T_dd1d4_row0_col2" class="data row0 col2" >13</td>
#     </tr>
#     <tr>
#       <th id="T_dd1d4_level0_row1" class="row_heading level0 row1" >Actual 1</th>
#       <td id="T_dd1d4_row1_col0" class="data row1 col0" >28</td>
#       <td id="T_dd1d4_row1_col1" class="data row1 col1" >1595</td>
#       <td id="T_dd1d4_row1_col2" class="data row1 col2" >14</td>
#     </tr>
#     <tr>
#       <th id="T_dd1d4_level0_row2" class="row_heading level0 row2" >Actual 2</th>
#       <td id="T_dd1d4_row2_col0" class="data row2 col0" >15</td>
#       <td id="T_dd1d4_row2_col1" class="data row2 col1" >93</td>
#       <td id="T_dd1d4_row2_col2" class="data row2 col2" >1467</td>
#     </tr>
#   </tbody>
# </table>

# %%
from sklearn.metrics import precision_score, recall_score, accuracy_score
# Calculate precision, recall, and accuracy using mean_probabilities_df
precision = precision_score(true_labels, predicted_labels, average='weighted')
recall = recall_score(true_labels, predicted_labels, average='weighted')
accuracy = accuracy_score(true_labels, predicted_labels)

print(f"Precision: {precision:.4f}")
print(f"Recall: {recall:.4f}")
print(f"Accuracy: {accuracy:.4f}")
# Out:
# Precision: 0.9193
# Recall: 0.9085
# Accuracy: 0.9085
