# %% [markdown]
# Packages:

# %%
import glob
import os
import warnings
 
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import pydicom
from pydicom.data import get_testdata_files
from sklearn.model_selection import train_test_split

from IPython.display import Markdown, display

 # Import functions from the module
import importlib
import help_files._0_definitions 
# import  help_files._1_visuals_script
# import  help_files._01_load_data
 # Reload the module to apply the changes to the script
importlib.reload(help_files._0_definitions)
 
# importlib.reload(help_files._01_load_data)
 
# Group by 'condition', 'level', and 'severity' and count occurrences
from help_files._0_definitions import count_severity_by_condition_level 
# Define the path
from pathlib import Path

pd.set_option("display.width", 1000)  # Set a large width to prevent line wrapping

# %%
### In definitions are all the functions that are used in the notebook and globals
with open("help_files/_0_definitions.py") as file:
    exec(file.read())
    ### In definitions are all the functions that are used in the notebook and globals
with open("help_files/_0_run_definitions.py") as file:
    exec(file.read())

# %%
# loading data
file_names = ["train_df_3_cat.csv", "test_df_3_cat.csv"]
# Load the data from the CSV files
dataframes = [pd.read_csv(data_path_vor / file_name) for file_name in file_names]
# Unpack the dataframes into separate variables
train_df, test_df = dataframes

print("DataFrames have been loaded successfully.")
# Out:
# DataFrames have been loaded successfully.

# %%
train_df.dtypes
# Out:
# study_id           int64
# severity         float64
# condition          int64
# level             object
# series_id        float64
# x                float64
# y                float64
# image_path        object
# missing_image       bool
# dtype: object

# %%
# # end sample or small sample    
if whole_data_set == False:
    print("Using the whole data set")
else:
    train_df = train_df.sample(n=100, random_state=RSEED)
    test_df = test_df.sample(n=100, random_state=RSEED)
    display(Markdown('<span style="color:red"> this is a small sample : 48692</span>'))
# Out:
# <span style="color:red"> this is a small sample : 48692</span>

# %% [markdown]
# Ttrasformaiton and dataloader (do not change over models)

# %%
# define transformation and class

import torch
from torch import nn, optim
from torch.utils.data import Dataset, DataLoader, random_split
# %pip install torch torchvision
import torchvision.models as models
from torchvision import transforms
import pydicom
# %pip install opencv-python
import cv2
import pandas as pd


# Define the transform with augmentation: I already tranformed i tbfore 

transform = transforms.Compose([
    transforms.ToPILImage(),
    transforms.Resize((224, 224)),
    #transforms.RandomHorizontalFlip(),  # Randomly flip the image horizontally
    #transforms.RandomRotation(2),       # Randomly rotate the image by ±10 degrees
    transforms.ColorJitter(brightness=0.2, contrast=0.2, saturation=0.2, hue=0.1),  # Adjust color properties
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
])


class MRIDataset(Dataset):
    def __init__(self, data, transform=None):
        self.data = data
        self.transform = transform

        # Ensure severity is in integer format
        self.data['severity'] = self.data['severity'].astype(int)

    def __getitem__(self, index):
        row = self.data.iloc[index]
        image_path = row['image_path']
        label = row['severity']  # Use severity for the label

        dicom_image = pydicom.dcmread(image_path)
        image = dicom_image.pixel_array.astype(float)
        image = (image / image.max() * 255).astype('uint8')  # Normalize

        # Convert the image to RGB if it is grayscale
        if len(image.shape) == 2:  # Grayscale
            image = cv2.cvtColor(image, cv2.COLOR_GRAY2RGB)

        # Apply transformations including augmentation
        image_tensor = self.transform(image) if self.transform else torch.from_numpy(image).permute(2, 0, 1)

        return image_tensor, torch.tensor(label).long()  # Return label as tensor

    def __len__(self):
        return len(self.data)

# %%
train_data = train_df

# %% [markdown]
# training model resnet50 sotp if validation and train go apart

# %% [markdown]
# * Setting the model

# %%
import mlflow
import mlflow.pytorch
import random
# Set random seed for reproducibility
seed = 42  # You can choose any integer
torch.manual_seed(seed)
np.random.seed(seed)  # Set seed for numpy
random.seed(seed)  # Set seed for random module

# Create a new experiment
Resnet50_class_seg1_seg1_basic = "Resnet50_class_seg1_seg1_basic"
mlflow.set_experiment(Resnet50_class_seg1_seg1_basic)
# Out:
# <Experiment: artifact_location='file:///c:/Users/HP1/Desktop/Spiced/capstone-project/mlruns/711328181724227740', creation_time=1731147338980, experiment_id='711328181724227740', last_update_time=1731147338980, lifecycle_stage='active', name='Resnet50_class_seg1_seg1_basic', tags={}>

# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader, random_split
from torchvision import models
# %pip install keras
# %pip install tensorflow
# from tensorflow.keras.callbacks import EarlyStopping  # Import EarlyStopping
import numpy as np  # Import numpy for setting the random seed

# Create the dataset
dataset = MRIDataset(data=train_data, transform=transform)

# Split the dataset into training and validation sets (80% train, 20% validation)
train_size = int(0.8 * len(dataset))
val_size = len(dataset) - train_size
train_dataset, val_dataset = random_split(dataset, [train_size, val_size])

batch_size = 256
# Create DataLoaders
train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
val_loader = DataLoader(val_dataset, batch_size=batch_size, shuffle=False)

# Load ResNet-50 and set up for classification
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
num_classes = train_df['severity'].nunique()

model = models.resnet50(weights='IMAGENET1K_V1')
model.fc = nn.Linear(model.fc.in_features, num_classes)
model.to(device)

# Define loss functions and optimizer
learining_rate = 0.0001 
criterion_cel = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters(), lr=learining_rate)
num_epochs = 20

# Early stopping parameters
# Lists to store loss values for plotting
train_losses_cel = []
val_losses_cel = []

# Early stopping parameters
diverge_count = 0              # Counter for divergence-based stopping
stop_threshold = 0.3           # Threshold for divergence
max_diverge_count = 3          # Max number of epochs with diverging validation loss
patience = 5  # Number of epochs to wait for improvement before early stopping


# Calculate number of layers in the model
num_layers = len(list(model.children()))

# %% [markdown]
# * setting mlflow: end running new model

# %%
import torch
import numpy as np
import os
import mlflow
import matplotlib.pyplot as plt

# Start MLflow run
with mlflow.start_run():
    # Log parameters
    mlflow.log_param("learning_rate", 'learning_rate')
    mlflow.log_param("optimizer", "Adam")
    mlflow.log_param("batch_size", 'batch_size')
    mlflow.log_param("num_epochs", num_epochs)
    mlflow.log_param("num_classes", num_classes)
    mlflow.log_param("model_architecture", "ResNet-50")
    
    # Log early stopping parameters
    mlflow.log_param("stop_threshold", stop_threshold)
    mlflow.log_param("max_diverge_count", max_diverge_count)
    mlflow.log_param("patience", patience)

    # Set descriptive tags for the model
    mlflow.set_tag("model_description", "ResNet-50 for 3 cat and Sagittal T2/STIR and Sagittal T1 images")

    # Example input tensor with the same shape as the model's expected input
    example_input = torch.randn(1, 3, 224, 224)  # Batch size 1, 3 color channels, 224x224 image
    best_val_loss = float('inf')  # Initialize best validation loss
    patience_counter = 0  # Plateau counter
    
    diverge_count = 0  # Counter for divergence-based stopping

    train_losses_cel = []  # List to store training losses
    val_losses_cel = []  # List to store validation losses

    for epoch in range(num_epochs):
        # Training phase
        model.train()
        running_loss_cel_train = 0.0

        for images, labels in train_loader:
            images, labels = images.to(device), labels.to(device)
            optimizer.zero_grad()
            
            outputs = model(images)
            
            # Cross Entropy Loss
            loss_cel = criterion_cel(outputs, labels)
            running_loss_cel_train += loss_cel.item()
            
            # Backward pass and optimization
            loss_cel.backward()
            optimizer.step()

        # Calculate average training loss for the epoch
        epoch_loss_cel_train = running_loss_cel_train / len(train_loader)
        train_losses_cel.append(epoch_loss_cel_train)

        # Log training loss to MLflow
        mlflow.log_metric("train_loss_cel", epoch_loss_cel_train, step=epoch)

        # Validation phase
        model.eval()
        running_loss_cel_val = 0.0

        with torch.no_grad():
            for images, labels in val_loader:
                images, labels = images.to(device), labels.to(device)
                outputs = model(images)
                
                # Cross Entropy Loss for validation
                loss_cel = criterion_cel(outputs, labels)
                running_loss_cel_val += loss_cel.item()

        # Calculate validation loss for the epoch
        epoch_loss_cel_val = running_loss_cel_val / len(val_loader)
        val_losses_cel.append(epoch_loss_cel_val)

        # Log validation loss to MLflow
        mlflow.log_metric("val_loss_cel", epoch_loss_cel_val, step=epoch)

        print(f'Epoch [{epoch + 1}/{num_epochs}], '
              f'Train Cross Entropy Loss: {epoch_loss_cel_train:.4f}, '
              f'Validation Cross Entropy Loss: {epoch_loss_cel_val:.4f}')

        # Save weights for each epoch
        epoch_weight_path = f"model_weights_epoch_{epoch + 1}.pt"
        torch.save(model.state_dict(), epoch_weight_path)
        mlflow.log_artifact(epoch_weight_path)  # Log model weights as artifact for each epoch
        os.remove(epoch_weight_path)  # Optionally, delete the local file after logging

        # Check for early stopping (divergence-based stopping)
        if epoch_loss_cel_val > epoch_loss_cel_train * (1 + stop_threshold):
            diverge_count += 1
            if diverge_count >= max_diverge_count:
                print(f"Early stopping at epoch {epoch + 1} due to validation loss diverging.")
                break
        else:
            diverge_count = 0  # Reset diverge count if validation loss is not diverging

        # Check for early stopping (plateau-based stopping)
        if epoch_loss_cel_val < best_val_loss:
            best_val_loss = epoch_loss_cel_val
            patience_counter = 0  # Reset plateau counter if validation loss improves
            # Save the model weights when validation loss improves (best model)
            best_model_weight_path = f"best_model_weights_epoch_{epoch + 1}.pt"
            torch.save(model.state_dict(), best_model_weight_path)
            mlflow.log_artifact(best_model_weight_path)  # Log the best model weights
            os.remove(best_model_weight_path)  # Optionally, delete the local file after logging
        else:
            patience_counter += 1
            if patience_counter >= patience:
                print(f"Early stopping at epoch {epoch + 1} due to lack of validation loss improvement.")
                break

    print("Training complete!")

    # Log final model
    example_input_np = example_input.numpy()
    mlflow.pytorch.log_model(model, "final_model", input_example=example_input_np)

    # Plot and log the loss curves as artifacts
    plt.figure(figsize=(10, 5))
    plt.plot(train_losses_cel, label='Train Cross Entropy Loss')
    plt.plot(val_losses_cel, label='Validation Cross Entropy Loss')
    plt.xlabel('Epoch')
    plt.ylabel('Loss')
    plt.title('Training and Validation Cross Entropy Loss')
    plt.legend()
    plt.savefig("cross_entropy_loss.png")
    mlflow.log_artifact("cross_entropy_loss.png")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[66], line 40
#      37 model.train()
#      38 running_loss_cel_train = 0.0
# ---> 40 for images, labels in train_loader:
#      41     images, labels = images.to(device), labels.to(device)
#      42     optimizer.zero_grad()
#
# File c:\Users\HP1\Desktop\Spiced\capstone-project\.venv\Lib\site-packages\torch\utils\data\dataloader.py:701, in _BaseDataLoaderIter.__next__(self)
#     698 if self._sampler_iter is None:
#     699     # TODO(https://github.com/pytorch/pytorch/issues/76750)
#     700     self._reset()  # type: ignore[call-arg]
# --> 701 data = self._next_data()
#     702 self._num_yielded += 1
#     703 if (
#     704     self._dataset_kind == _DatasetKind.Iterable
#     705     and self._IterableDataset_len_called is not None
#     706     and self._num_yielded > self._IterableDataset_len_called
#     707 ):
#
# File c:\Users\HP1\Desktop\Spiced\capstone-project\.venv\Lib\site-packages\torch\utils\data\dataloader.py:757, in _SingleProcessDataLoaderIter._next_data(self)
#     755 def _next_data(self):
#     756     index = self._next_index()  # may raise StopIteration
# --> 757     data = self._dataset_fetcher.fetch(index)  # may raise StopIteration
#     758     if self._pin_memory:
#     759         data = _utils.pin_memory.pin_memory(data, self._pin_memory_device)
#
# File c:\Users\HP1\Desktop\Spiced\capstone-project\.venv\Lib\site-packages\torch\utils\data\_utils\fetch.py:50, in _MapDatasetFetcher.fetch(self, possibly_batched_index)
#      48 if self.auto_collation:
#      49     if hasattr(self.dataset, "__getitems__") and self.dataset.__getitems__:
# ---> 50         data = self.dataset.__getitems__(possibly_batched_index)
#      51     else:
#      52         data = [self.dataset[idx] for idx in possibly_batched_index]
#
# File c:\Users\HP1\Desktop\Spiced\capstone-project\.venv\Lib\site-packages\torch\utils\data\dataset.py:420, in Subset.__getitems__(self, indices)
#     418     return self.dataset.__getitems__([self.indices[idx] for idx in indices])  # type: ignore[attr-defined]
#     419 else:
# --> 420     return [self.dataset[self.indices[idx]] for idx in indices]
#
# File c:\Users\HP1\Desktop\Spiced\capstone-project\.venv\Lib\site-packages\torch\utils\data\dataset.py:420, in <listcomp>(.0)
#     418     return self.dataset.__getitems__([self.indices[idx] for idx in indices])  # type: ignore[attr-defined]
#     419 else:
# --> 420     return [self.dataset[self.indices[idx]] for idx in indices]
#
# Cell In[62], line 41, in MRIDataset.__getitem__(self, index)
#      38 image_path = row['image_path']
#      39 label = row['severity']  # Use severity for the label
# ---> 41 dicom_image = pydicom.dcmread(image_path)
#      42 image = dicom_image.pixel_array.astype(float)
#      43 image = (image / image.max() * 255).astype('uint8')  # Normalize
#
# File c:\Users\HP1\Desktop\Spiced\capstone-project\.venv\Lib\site-packages\pydicom\filereader.py:1042, in dcmread(fp, defer_size, stop_before_pixels, force, specific_tags)
#    1040     caller_owns_file = False
#    1041     logger.debug(f"Reading file '{fp}'")
# -> 1042     fp = open(fp, "rb")
#    1043 elif (
#    1044     fp is None
#    1045     or not hasattr(fp, "read")
#    1046     or not hasattr(fp, "seek")
#    1047     or not hasattr(fp, "tell")
#    1048 ):
#    1049     raise TypeError(
#    1050         "dcmread: Expected a file path, file-like or readable buffer, "
#    1051         f"but got {type(fp).__name__}"
#    1052     )
#
# FileNotFoundError: [Errno 2] No such file or directory: 'data/train_images_origin/2383836357/217610363/16.dcm'

# %%
ss

# %%
loaded_model = mlflow.pytorch.load_model("runs:/deaa903e488043d19aad572a6c429479/final_model")
print(loaded_model)

# %%
import torch
import torchvision.models as models

# Step 1: Define the model architecture (same as training)
model_for_prediciton = models.resnet50()
model_for_prediciton.fc = torch.nn.Linear(model_for_prediciton.fc.in_features, 3)  # Update for your classes

# Step 2: Load the best model weights
# Adjust this path if necessary
best_weights_path = "C:/Users/HP1/Desktop/Spiced/capstone-project/mlruns/711328181724227740/deaa903e488043d19aad572a6c429479/artifacts/best_model_weights_epoch_1.pt"
model_for_prediciton.load_state_dict(torch.load(best_weights_path))

# Step 3: Set the model to evaluation mode
model_for_prediciton.eval()
model_for_prediciton.to(torch.device('cuda' if torch.cuda.is_available() else 'cpu'))

# %%
# Replace <run_id> with your actual run ID and <path_to_model> with the artifact path used during logging
model_path = r"C:\Users\HP1\Desktop\Spiced\capstone-project\mlruns\711328181724227740\deaa903e488043d19aad572a6c429479\artifacts\final_model"
model_for_prediciton = mlflow.pytorch.load_model(model_path)

model_for_prediciton.eval()  # Set the model to evaluation mode
# Out:
# ResNet(
#   (conv1): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#   (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (relu): ReLU(inplace=True)
#   (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   (layer1): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (downsample): Sequential(
#         (0): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Bottleneck(
#       (conv1): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (2): Bottleneck(
#       (conv1): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#   )
#   (layer2): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (downsample): Sequential(
#         (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Bottleneck(
#       (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (2): Bottleneck(
#       (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (3): Bottleneck(
#       (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#   )
#   (layer3): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (downsample): Sequential(
#         (0): Conv2d(512, 1024, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (2): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (3): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (4): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (5): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#   )
#   (layer4): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(1024, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (downsample): Sequential(
#         (0): Conv2d(1024, 2048, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Bottleneck(
#       (conv1): Conv2d(2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (2): Bottleneck(
#       (conv1): Conv2d(2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#   )
#   (avgpool): AdaptiveAvgPool2d(output_size=(1, 1))
#   (fc): Linear(in_features=2048, out_features=3, bias=True)
# )

# %% [markdown]
# Restore parameters and metrtics from mlflow

# %% [markdown]
# I should take prdicted probabilities and not predicted classes: output scores (logits) are converted into probabilities using the softmax function

# %%
# class definition
import mlflow
import mlflow.pytorch
import torch
from torch import nn, optim
from torch.utils.data import Dataset, DataLoader, random_split
import torchvision.models as models
from torchvision import transforms
import pydicom
import cv2
import pandas as pd
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
import matplotlib.pyplot as plt
import numpy as np



# Load the model
model = model_for_prediciton
model.to(torch.device('cuda' if torch.cuda.is_available() else 'cpu'))  # Move model to appropriate device
model.eval()  # Set the model to evaluation mode

# Prepare data
transform = transforms.Compose([
    transforms.ToPILImage(),
    transforms.Resize((224, 224)),
    transforms.ColorJitter(brightness=0.2, contrast=0.2, saturation=0.2, hue=0.1),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
])

class MRIDataset(Dataset):
    def __init__(self, data, transform=None):
        self.data = data
        self.transform = transform
        self.data['severity'] = self.data['severity'].astype(int)

    def __getitem__(self, index):
        row = self.data.iloc[index]
        image_path = row['image_path']
        label = row['severity']
        dicom_image = pydicom.dcmread(image_path)
        image = dicom_image.pixel_array.astype(float)
        image = (image / image.max() * 255).astype('uint8')
        if len(image.shape) == 2:  # Grayscale
            image = cv2.cvtColor(image, cv2.COLOR_GRAY2RGB)
        image_tensor = self.transform(image) if self.transform else torch.from_numpy(image).permute(2, 0, 1)
        return image_tensor, torch.tensor(label).long()

    def __len__(self):
        return len(self.data)

# %% [markdown]
# predicting probabilities for test data

# %%
test_data = test_df

# %%
# calculate prbabilities and probability list
test_dataset = MRIDataset(data=test_data, transform=transform)
test_loader = DataLoader(test_dataset, batch_size=1, shuffle=False)

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print(f"Using device: {device}")

# Inference loop with probability extraction
results = []
probabilities_list = []

with torch.no_grad():
    for images, labels in test_loader:
        images = images.to(device)
        labels = labels.to(device)  # Ensure labels are also on the correct device
        outputs = model(images)
        probabilities = torch.softmax(outputs, dim=1)  # Calculate class probabilities
        _, predicted_classes = torch.max(outputs, 1)
        
        # Append predictions and probabilities
        results.append(predicted_classes.item())
        probabilities_list.append(probabilities.cpu().numpy())
# Out:
# Using device: cpu

# %%
# Print predicted classes and their probabilities
for i, (pred, probs) in enumerate(zip(results, probabilities_list)):
    print(f"Test image {i}: Predicted class {pred}, Probabilities: {probs}")

# Additional code to plot the confusion matrix can stay as-is:
true_labels = []
predicted_labels = []

for images, labels in test_loader:
    images = images.to(device)
    true_labels.extend(labels.numpy())

    with torch.no_grad():
        outputs = model(images)
        _, predicted_classes = torch.max(outputs, 1)
        predicted_labels.extend(predicted_classes.cpu().numpy())

true_labels = np.array(true_labels)
predicted_labels = np.array(predicted_labels)

print("True Labels Unique Values:", np.unique(true_labels))
print("Predicted Labels Unique Values:", np.unique(predicted_labels))
# Out:
# Test image 0: Predicted class 0, Probabilities: [[9.9618053e-01 3.8086153e-03 1.0922757e-05]]
# Test image 1: Predicted class 1, Probabilities: [[1.4524867e-08 9.9999774e-01 2.2434274e-06]]
# Test image 2: Predicted class 1, Probabilities: [[0.00616368 0.99165326 0.00218306]]
# Test image 3: Predicted class 1, Probabilities: [[2.4807669e-05 9.9992085e-01 5.4300079e-05]]
# Test image 4: Predicted class 1, Probabilities: [[6.2356039e-04 9.9937123e-01 5.2000514e-06]]
# Test image 5: Predicted class 1, Probabilities: [[2.5383797e-03 9.9739408e-01 6.7593719e-05]]
# Test image 6: Predicted class 1, Probabilities: [[0.01508838 0.805109   0.1798026 ]]
# Test image 7: Predicted class 1, Probabilities: [[2.2381102e-05 9.9987686e-01 1.0066373e-04]]
# Test image 8: Predicted class 1, Probabilities: [[6.9637747e-07 9.9986064e-01 1.3865811e-04]]
# Test image 9: Predicted class 0, Probabilities: [[0.9500599  0.04504139 0.00489869]]
# Test image 10: Predicted class 0, Probabilities: [[9.9889874e-01 1.0764807e-03 2.4710189e-05]]
# Test image 11: Predicted class 1, Probabilities: [[0.0597745  0.937908   0.00231759]]
# Test image 12: Predicted class 0, Probabilities: [[9.9821824e-01 1.7802971e-03 1.4287949e-06]]
# Test image 13: Predicted class 1, Probabilities: [[7.7836089e-02 9.2203391e-01 1.2997467e-04]]
# Test image 14: Predicted class 1, Probabilities: [[5.8668800e-02 9.4120824e-01 1.2296255e-04]]
# Test image 15: Predicted class 1, Probabilities: [[1.1343297e-02 9.8778665e-01 8.7005872e-04]]
# Test image 16: Predicted class 1, Probabilities: [[1.3985896e-03 9.9847895e-01 1.2248175e-04]]
# Test image 17: Predicted class 1, Probabilities: [[3.3367775e-02 9.6660268e-01 2.9640907e-05]]
# Test image 18: Predicted class 1, Probabilities: [[2.4105483e-03 9.9758315e-01 6.2463205e-06]]
# Test image 19: Predicted class 1, Probabilities: [[1.1785999e-04 9.9987960e-01 2.5173695e-06]]
# Test image 20: Predicted class 1, Probabilities: [[2.1757178e-01 7.8239614e-01 3.2102242e-05]]
# Test image 21: Predicted class 1, Probabilities: [[3.5803437e-03 9.9620783e-01 2.1183267e-04]]
# Test image 22: Predicted class 1, Probabilities: [[1.5033243e-03 9.9848467e-01 1.2073849e-05]]
# Test image 23: Predicted class 1, Probabilities: [[7.0476369e-04 9.9914062e-01 1.5461404e-04]]
# Test image 24: Predicted class 0, Probabilities: [[9.9996221e-01 3.7245034e-05 5.7737913e-07]]
# Test image 25: Predicted class 1, Probabilities: [[0.29342097 0.6171275  0.08945154]]
# Test image 26: Predicted class 0, Probabilities: [[9.9999607e-01 2.5090865e-06 1.4786439e-06]]
# Test image 27: Predicted class 0, Probabilities: [[9.9976128e-01 1.9179100e-04 4.6923462e-05]]
# Test image 28: Predicted class 0, Probabilities: [[9.8783189e-01 1.2161477e-02 6.6282169e-06]]
# Test image 29: Predicted class 0, Probabilities: [[9.8829764e-01 1.1673473e-02 2.8856708e-05]]
# Test image 30: Predicted class 0, Probabilities: [[0.9607518  0.03650565 0.00274255]]
# Test image 31: Predicted class 0, Probabilities: [[9.9847811e-01 1.3856421e-03 1.3627442e-04]]
# Test image 32: Predicted class 0, Probabilities: [[9.9442744e-01 5.4939287e-03 7.8583122e-05]]
# Test image 33: Predicted class 2, Probabilities: [[0.1912026  0.23271312 0.5760843 ]]
# Test image 34: Predicted class 2, Probabilities: [[0.01165254 0.22932649 0.759021  ]]
# Test image 35: Predicted class 2, Probabilities: [[0.0208129  0.13058777 0.8485993 ]]
# Test image 36: Predicted class 2, Probabilities: [[0.00574941 0.0231659  0.97108465]]
# Test image 37: Predicted class 2, Probabilities: [[0.00334175 0.31997222 0.67668605]]
# Test image 70: Predicted class 1, Probabilities: [[2.4011826e-04 9.9973601e-01 2.3883986e-05]]
# Test image 71: Predicted class 0, Probabilities: [[9.8131162e-01 1.7863829e-02 8.2457316e-04]]
# Test image 72: Predicted class 0, Probabilities: [[9.9982578e-01 1.5384535e-04 2.0353062e-05]]
# Test image 73: Predicted class 0, Probabilities: [[9.9298334e-01 6.7381337e-03 2.7849461e-04]]
# Test image 74: Predicted class 1, Probabilities: [[0.41557372 0.58298695 0.00143934]]
# Test image 75: Predicted class 1, Probabilities: [[7.9910214e-06 9.9998307e-01 8.9115265e-06]]
# Test image 76: Predicted class 1, Probabilities: [[3.1948824e-05 9.9996042e-01 7.5803091e-06]]
# Test image 77: Predicted class 1, Probabilities: [[0.00118    0.9956221  0.00319793]]
# Test image 78: Predicted class 2, Probabilities: [[0.03006244 0.2512382  0.7186994 ]]
# Test image 79: Predicted class 1, Probabilities: [[7.5947486e-05 9.9991465e-01 9.4512634e-06]]
# Test image 80: Predicted class 0, Probabilities: [[9.9771690e-01 2.1886749e-03 9.4465526e-05]]
# Test image 81: Predicted class 1, Probabilities: [[1.0004141e-05 9.9998736e-01 2.6178125e-06]]
# Test image 82: Predicted class 1, Probabilities: [[6.7573194e-05 9.9964106e-01 2.9134678e-04]]
# Test image 83: Predicted class 1, Probabilities: [[3.4463627e-04 9.9712843e-01 2.5270171e-03]]
# Test image 84: Predicted class 1, Probabilities: [[3.3443470e-05 9.9974686e-01 2.1961911e-04]]
# Test image 85: Predicted class 1, Probabilities: [[1.8331491e-03 9.9816030e-01 6.5233939e-06]]
# Test image 86: Predicted class 1, Probabilities: [[1.0574133e-03 9.9860954e-01 3.3293362e-04]]
# Test image 87: Predicted class 1, Probabilities: [[3.6140540e-04 9.9855262e-01 1.0859584e-03]]
# Test image 88: Predicted class 1, Probabilities: [[4.2603942e-04 9.9934310e-01 2.3082717e-04]]
# Test image 89: Predicted class 1, Probabilities: [[2.6675771e-05 9.9991477e-01 5.8517555e-05]]
# Test image 90: Predicted class 1, Probabilities: [[1.1680924e-03 9.9840766e-01 4.2434566e-04]]
# Test image 91: Predicted class 1, Probabilities: [[2.2338780e-03 9.9719644e-01 5.6961901e-04]]
# Test image 92: Predicted class 1, Probabilities: [[4.0503573e-06 9.9999583e-01 1.6369707e-07]]
# Test image 93: Predicted class 1, Probabilities: [[3.7992915e-05 9.9980289e-01 1.5914363e-04]]
# Test image 94: Predicted class 0, Probabilities: [[9.9875402e-01 1.2356775e-03 1.0268531e-05]]
# Test image 95: Predicted class 0, Probabilities: [[9.9999583e-01 3.6374713e-06 4.7357693e-07]]
# Test image 96: Predicted class 0, Probabilities: [[9.89603221e-01 1.03959255e-02 8.27927636e-07]]
# Test image 97: Predicted class 0, Probabilities: [[9.95822668e-01 4.05934639e-03 1.17963544e-04]]
# Test image 98: Predicted class 1, Probabilities: [[2.6589456e-01 7.3387855e-01 2.2695989e-04]]
# Test image 99: Predicted class 0, Probabilities: [[9.950277e-01 4.909730e-03 6.247995e-05]]
# Test image 131: Predicted class 0, Probabilities: [[9.7036135e-01 2.9068103e-02 5.7047833e-04]]
# Test image 132: Predicted class 0, Probabilities: [[9.9885046e-01 1.1388832e-03 1.0544484e-05]]
# Test image 133: Predicted class 1, Probabilities: [[4.881681e-03 9.950570e-01 6.136978e-05]]
# Test image 134: Predicted class 1, Probabilities: [[4.3943496e-03 9.9514306e-01 4.6264523e-04]]
# Test image 135: Predicted class 1, Probabilities: [[6.2501186e-04 9.9928790e-01 8.7023967e-05]]
# Test image 136: Predicted class 1, Probabilities: [[1.1516664e-03 9.9879187e-01 5.6439003e-05]]
# Test image 137: Predicted class 1, Probabilities: [[4.3712235e-03 9.9544829e-01 1.8052125e-04]]
# Test image 138: Predicted class 1, Probabilities: [[3.4298602e-05 9.9996102e-01 4.6819046e-06]]
# Test image 139: Predicted class 1, Probabilities: [[1.6251355e-04 9.9974579e-01 9.1666778e-05]]
# Test image 140: Predicted class 0, Probabilities: [[0.7708559  0.03022817 0.1989159 ]]
# Test image 141: Predicted class 1, Probabilities: [[1.8368625e-04 9.9980849e-01 7.8997455e-06]]
# Test image 142: Predicted class 0, Probabilities: [[8.4953660e-01 1.5030082e-01 1.6264709e-04]]
# Test image 143: Predicted class 1, Probabilities: [[5.420091e-07 9.999993e-01 6.168132e-08]]
# Test image 144: Predicted class 1, Probabilities: [[6.982345e-03 9.930153e-01 2.324500e-06]]
# Test image 145: Predicted class 1, Probabilities: [[6.2920421e-02 9.3703783e-01 4.1724954e-05]]
# Test image 146: Predicted class 1, Probabilities: [[7.1266113e-04 9.9923468e-01 5.2699314e-05]]
# Test image 147: Predicted class 1, Probabilities: [[1.2160051e-03 9.9873680e-01 4.7291709e-05]]
# Test image 148: Predicted class 0, Probabilities: [[9.9992394e-01 5.7960075e-05 1.8085460e-05]]
# Test image 149: Predicted class 0, Probabilities: [[9.9951816e-01 3.7707857e-04 1.0467738e-04]]
# Test image 150: Predicted class 0, Probabilities: [[0.9936579  0.00462457 0.00171762]]
# Test image 151: Predicted class 2, Probabilities: [[6.1460196e-05 9.5283426e-03 9.9041021e-01]]
# Test image 152: Predicted class 2, Probabilities: [[0.01853613 0.00254687 0.978917  ]]
# Test image 153: Predicted class 2, Probabilities: [[3.2325403e-03 6.3127035e-04 9.9613613e-01]]
# Test image 154: Predicted class 2, Probabilities: [[0.00121266 0.3195638  0.67922354]]
# Test image 155: Predicted class 2, Probabilities: [[1.6664722e-04 5.0812389e-04 9.9932528e-01]]
# Test image 156: Predicted class 2, Probabilities: [[1.9971861e-03 8.5995527e-04 9.9714285e-01]]
# Test image 157: Predicted class 2, Probabilities: [[8.4444917e-05 2.0289802e-04 9.9971265e-01]]
# Test image 158: Predicted class 2, Probabilities: [[0.00166246 0.00111904 0.9972185 ]]
# Test image 159: Predicted class 2, Probabilities: [[0.00101768 0.0022258  0.9967565 ]]
# Test image 160: Predicted class 2, Probabilities: [[0.00397444 0.02278921 0.9732363 ]]
# Test image 161: Predicted class 2, Probabilities: [[4.6812429e-04 1.4591259e-02 9.8494059e-01]]
# Test image 162: Predicted class 2, Probabilities: [[1.16206844e-04 2.59814458e-03 9.97285604e-01]]
# Test image 194: Predicted class 1, Probabilities: [[1.4694693e-03 9.9840659e-01 1.2407052e-04]]
# Test image 195: Predicted class 0, Probabilities: [[0.88296074 0.11555165 0.00148762]]
# Test image 196: Predicted class 0, Probabilities: [[9.9981767e-01 1.4722950e-04 3.5112833e-05]]
# Test image 197: Predicted class 0, Probabilities: [[9.9249661e-01 7.1715224e-03 3.3192814e-04]]
# Test image 198: Predicted class 0, Probabilities: [[0.96256745 0.01795907 0.01947342]]
# Test image 199: Predicted class 0, Probabilities: [[9.5972174e-01 4.0277813e-02 4.9887467e-07]]
# Test image 200: Predicted class 0, Probabilities: [[9.9986207e-01 1.3733779e-04 5.5083967e-07]]
# Test image 201: Predicted class 1, Probabilities: [[5.086889e-03 9.949084e-01 4.769883e-06]]
# Test image 202: Predicted class 1, Probabilities: [[7.3348451e-07 9.9999845e-01 8.1091838e-07]]
# Test image 203: Predicted class 1, Probabilities: [[4.2106453e-06 9.9999499e-01 8.3715400e-07]]
# Test image 204: Predicted class 1, Probabilities: [[2.5615336e-05 9.9997401e-01 3.7732948e-07]]
# Test image 205: Predicted class 1, Probabilities: [[3.7133884e-07 9.9999952e-01 1.2941268e-07]]
# Test image 206: Predicted class 1, Probabilities: [[8.7195024e-04 9.9908936e-01 3.8760569e-05]]
# Test image 207: Predicted class 1, Probabilities: [[1.4912139e-06 9.9999821e-01 2.0037780e-07]]
# Test image 208: Predicted class 0, Probabilities: [[0.7101454  0.27778253 0.0120721 ]]
# Test image 209: Predicted class 0, Probabilities: [[9.9940240e-01 5.1439798e-04 8.3167724e-05]]
# Test image 210: Predicted class 0, Probabilities: [[0.98173714 0.00184436 0.01641857]]
# Test image 211: Predicted class 1, Probabilities: [[0.07948965 0.58704    0.33347034]]
# Test image 212: Predicted class 1, Probabilities: [[2.4037328e-05 9.9994457e-01 3.1337884e-05]]
# Test image 213: Predicted class 1, Probabilities: [[8.0897352e-03 9.9174577e-01 1.6459293e-04]]
# Test image 214: Predicted class 1, Probabilities: [[7.7450834e-04 9.9921191e-01 1.3602121e-05]]
# Test image 215: Predicted class 1, Probabilities: [[2.5048163e-03 9.9748862e-01 6.5402010e-06]]
# Test image 216: Predicted class 1, Probabilities: [[6.484266e-04 9.992799e-01 7.165285e-05]]
# Test image 217: Predicted class 1, Probabilities: [[9.184266e-03 9.907952e-01 2.058701e-05]]
# Test image 218: Predicted class 1, Probabilities: [[2.3950322e-03 9.9760050e-01 4.5243487e-06]]
# Test image 219: Predicted class 1, Probabilities: [[5.3062867e-02 9.4657284e-01 3.6421572e-04]]
# Test image 220: Predicted class 1, Probabilities: [[9.4143026e-05 9.9988210e-01 2.3743074e-05]]
# Test image 221: Predicted class 1, Probabilities: [[2.3532631e-02 9.7600693e-01 4.6044835e-04]]
# Test image 222: Predicted class 0, Probabilities: [[9.7564042e-01 2.4344293e-02 1.5212335e-05]]
# Test image 223: Predicted class 0, Probabilities: [[9.9821448e-01 9.0277015e-04 8.8271446e-04]]
# Test image 224: Predicted class 0, Probabilities: [[9.6380734e-01 3.6008202e-02 1.8435089e-04]]
# Test image 255: Predicted class 0, Probabilities: [[9.9871016e-01 1.2685531e-03 2.1313830e-05]]
# Test image 256: Predicted class 0, Probabilities: [[9.6070951e-01 3.9193675e-02 9.6752898e-05]]
# Test image 257: Predicted class 0, Probabilities: [[9.6026874e-01 3.8835946e-02 8.9532451e-04]]
# Test image 258: Predicted class 2, Probabilities: [[2.1389242e-04 8.6000880e-05 9.9970019e-01]]
# Test image 259: Predicted class 2, Probabilities: [[0.00197138 0.00690586 0.9911227 ]]
# Test image 260: Predicted class 2, Probabilities: [[1.2232494e-04 6.7893812e-04 9.9919873e-01]]
# Test image 261: Predicted class 2, Probabilities: [[4.4925598e-04 1.5919261e-03 9.9795878e-01]]
# Test image 262: Predicted class 2, Probabilities: [[2.1895174e-04 1.5050472e-02 9.8473060e-01]]
# Test image 263: Predicted class 2, Probabilities: [[9.0981222e-04 2.7819483e-03 9.9630827e-01]]
# Test image 264: Predicted class 2, Probabilities: [[7.5118325e-05 8.1268034e-04 9.9911219e-01]]
# Test image 265: Predicted class 2, Probabilities: [[0.01156625 0.12377433 0.86465937]]
# Test image 266: Predicted class 2, Probabilities: [[4.3208664e-04 9.0936344e-04 9.9865854e-01]]
# Test image 267: Predicted class 2, Probabilities: [[7.8890595e-04 8.2550151e-03 9.9095613e-01]]
# Test image 268: Predicted class 2, Probabilities: [[0.0073166  0.01216438 0.98051906]]
# Test image 269: Predicted class 2, Probabilities: [[0.00919368 0.00772821 0.9830782 ]]
# Test image 270: Predicted class 2, Probabilities: [[0.01741958 0.00365093 0.97892946]]
# Test image 271: Predicted class 2, Probabilities: [[0.00397419 0.05731109 0.9387147 ]]
# Test image 272: Predicted class 2, Probabilities: [[0.13037142 0.03189024 0.8377384 ]]
# Test image 273: Predicted class 2, Probabilities: [[4.1378813e-04 1.5263582e-04 9.9943358e-01]]
# Test image 274: Predicted class 2, Probabilities: [[0.01003094 0.03389004 0.95607907]]
# Test image 275: Predicted class 2, Probabilities: [[1.4343408e-03 1.3359936e-04 9.9843210e-01]]
# Test image 276: Predicted class 2, Probabilities: [[0.00396065 0.00312062 0.99291867]]
# Test image 277: Predicted class 2, Probabilities: [[1.4353245e-04 3.2561287e-04 9.9953091e-01]]
# Test image 278: Predicted class 1, Probabilities: [[1.3617816e-04 9.9984455e-01 1.9204244e-05]]
# Test image 279: Predicted class 1, Probabilities: [[8.2199483e-07 9.9999249e-01 6.6682019e-06]]
# Test image 280: Predicted class 1, Probabilities: [[3.7979447e-05 9.9996126e-01 6.9210273e-07]]
# Test image 281: Predicted class 1, Probabilities: [[3.0367717e-05 9.9996722e-01 2.4094368e-06]]
# Test image 282: Predicted class 1, Probabilities: [[2.9822018e-03 9.9661839e-01 3.9936785e-04]]
# Test image 283: Predicted class 1, Probabilities: [[2.9739359e-04 9.9955457e-01 1.4802623e-04]]
# Test image 284: Predicted class 1, Probabilities: [[3.6739301e-02 9.6306378e-01 1.9687253e-04]]
# Test image 285: Predicted class 1, Probabilities: [[2.8559323e-05 9.9997008e-01 1.3048175e-06]]
# Test image 286: Predicted class 1, Probabilities: [[0.00136491 0.996083   0.00255195]]
# Test image 349: Predicted class 1, Probabilities: [[1.3380330e-03 9.9856395e-01 9.8117554e-05]]
# Test image 350: Predicted class 1, Probabilities: [[7.9150486e-05 9.9991786e-01 3.0232186e-06]]
# Test image 351: Predicted class 1, Probabilities: [[3.0839237e-04 9.9968946e-01 2.1589540e-06]]
# Test image 352: Predicted class 1, Probabilities: [[7.2784924e-06 9.9999201e-01 7.1089062e-07]]
# Test image 353: Predicted class 0, Probabilities: [[9.9749410e-01 2.4499872e-03 5.5833127e-05]]
# Test image 354: Predicted class 1, Probabilities: [[1.4129437e-03 9.9855763e-01 2.9356388e-05]]
# Test image 355: Predicted class 1, Probabilities: [[3.5113352e-03 9.9647361e-01 1.5060922e-05]]
# Test image 356: Predicted class 0, Probabilities: [[9.951428e-01 4.443863e-03 4.133021e-04]]
# Test image 357: Predicted class 0, Probabilities: [[9.8168439e-01 1.7729456e-02 5.8621814e-04]]
# Test image 358: Predicted class 0, Probabilities: [[9.9953830e-01 4.5968671e-04 2.0186585e-06]]
# Test image 359: Predicted class 1, Probabilities: [[1.8135600e-01 8.1855851e-01 8.5499145e-05]]
# Test image 360: Predicted class 0, Probabilities: [[0.5039712  0.48168534 0.01434343]]
# Test image 361: Predicted class 0, Probabilities: [[9.9748802e-01 2.3560694e-03 1.5589972e-04]]
# Test image 362: Predicted class 0, Probabilities: [[0.97567457 0.02012361 0.00420179]]
# Test image 363: Predicted class 0, Probabilities: [[9.9329442e-01 6.2388936e-03 4.6661467e-04]]
# Test image 364: Predicted class 0, Probabilities: [[9.9107695e-01 8.6079938e-03 3.1509696e-04]]
# Test image 365: Predicted class 0, Probabilities: [[9.9862051e-01 1.3499182e-03 2.9525188e-05]]
# Test image 366: Predicted class 0, Probabilities: [[9.7200352e-01 2.7961956e-02 3.4547102e-05]]
# Test image 367: Predicted class 1, Probabilities: [[1.5311762e-06 9.9992990e-01 6.8587848e-05]]
# Test image 368: Predicted class 1, Probabilities: [[2.2442249e-04 9.9661189e-01 3.1636953e-03]]
# Test image 369: Predicted class 1, Probabilities: [[8.3176365e-06 9.9999118e-01 5.0883671e-07]]
# Test image 370: Predicted class 1, Probabilities: [[8.3205805e-07 9.9995065e-01 4.8466634e-05]]
# Test image 371: Predicted class 1, Probabilities: [[5.9087604e-05 9.9925536e-01 6.8549131e-04]]
# Test image 372: Predicted class 1, Probabilities: [[1.0043782e-05 9.9997568e-01 1.4352053e-05]]
# Test image 373: Predicted class 1, Probabilities: [[1.6362009e-04 9.9960130e-01 2.3509511e-04]]
# Test image 374: Predicted class 1, Probabilities: [[0.01371033 0.98362684 0.00266274]]
# Test image 375: Predicted class 0, Probabilities: [[9.9558324e-01 4.2259237e-03 1.9089754e-04]]
# Test image 376: Predicted class 0, Probabilities: [[0.9894064  0.00950665 0.00108697]]
# Test image 377: Predicted class 0, Probabilities: [[0.9514804  0.04589305 0.00262655]]
# Test image 378: Predicted class 0, Probabilities: [[9.566873e-01 4.272738e-02 5.853705e-04]]
# Test image 379: Predicted class 0, Probabilities: [[0.90807736 0.09098062 0.00094205]]
# Test image 380: Predicted class 0, Probabilities: [[7.9190683e-01 2.0740661e-01 6.8655331e-04]]
# Test image 381: Predicted class 0, Probabilities: [[9.7806066e-01 2.1225668e-02 7.1367488e-04]]
# Test image 382: Predicted class 0, Probabilities: [[7.2417080e-01 2.7573037e-01 9.8761477e-05]]
# Test image 383: Predicted class 0, Probabilities: [[0.8508053  0.13507129 0.01412351]]
# Test image 384: Predicted class 2, Probabilities: [[0.00261754 0.07502586 0.92235655]]
# Test image 385: Predicted class 2, Probabilities: [[0.04939085 0.04945448 0.90115464]]
# Test image 386: Predicted class 2, Probabilities: [[0.00219164 0.02802595 0.9697824 ]]
# Test image 387: Predicted class 2, Probabilities: [[0.00156738 0.01701551 0.9814171 ]]
# Test image 388: Predicted class 2, Probabilities: [[0.01451308 0.08217672 0.9033102 ]]
# Test image 389: Predicted class 2, Probabilities: [[0.01054508 0.00156568 0.98788923]]
# Test image 390: Predicted class 1, Probabilities: [[0.00567173 0.97159696 0.02273126]]
# Test image 391: Predicted class 2, Probabilities: [[0.00695859 0.00101168 0.99202967]]
# Test image 392: Predicted class 2, Probabilities: [[0.29264957 0.26507217 0.44227833]]
# Test image 393: Predicted class 2, Probabilities: [[0.00106531 0.00224482 0.9966898 ]]
# Test image 394: Predicted class 2, Probabilities: [[0.00980832 0.04729271 0.9428989 ]]
# Test image 395: Predicted class 0, Probabilities: [[0.5489875  0.16902854 0.28198403]]
# Test image 396: Predicted class 0, Probabilities: [[0.8454567  0.02656331 0.12797995]]
# Test image 397: Predicted class 2, Probabilities: [[0.00751092 0.19369005 0.79879904]]
# Test image 398: Predicted class 2, Probabilities: [[0.00608774 0.01822172 0.97569054]]
# Test image 399: Predicted class 0, Probabilities: [[0.66944814 0.22165091 0.10890099]]
# Test image 400: Predicted class 2, Probabilities: [[0.02655585 0.01110486 0.96233934]]
# Test image 401: Predicted class 0, Probabilities: [[0.598966   0.04664329 0.35439074]]
# Test image 402: Predicted class 2, Probabilities: [[0.0307427  0.06158048 0.9076769 ]]
# Test image 403: Predicted class 2, Probabilities: [[0.00372178 0.00599097 0.9902872 ]]
# Test image 404: Predicted class 0, Probabilities: [[9.9816543e-01 1.5843587e-03 2.5024067e-04]]
# Test image 405: Predicted class 0, Probabilities: [[0.56461895 0.33627832 0.09910266]]
# Test image 406: Predicted class 0, Probabilities: [[0.98955554 0.00708325 0.0033611 ]]
# Test image 407: Predicted class 0, Probabilities: [[9.929428e-01 6.479257e-03 5.779554e-04]]
# Test image 408: Predicted class 0, Probabilities: [[9.9748045e-01 1.9097854e-03 6.0973037e-04]]
# Test image 409: Predicted class 0, Probabilities: [[0.6095238  0.27239943 0.11807679]]
# Test image 410: Predicted class 1, Probabilities: [[0.2681428  0.70941144 0.02244571]]
# Test image 411: Predicted class 1, Probabilities: [[5.2946955e-03 9.9454272e-01 1.6251672e-04]]
# Test image 412: Predicted class 0, Probabilities: [[9.992945e-01 7.044831e-04 9.975604e-07]]
# Test image 413: Predicted class 1, Probabilities: [[4.2414308e-01 5.7559413e-01 2.6279272e-04]]
# Test image 414: Predicted class 0, Probabilities: [[0.9235583  0.07265832 0.0037834 ]]
# Test image 415: Predicted class 2, Probabilities: [[0.00128559 0.00552413 0.9931902 ]]
# Test image 416: Predicted class 2, Probabilities: [[2.9216713e-04 6.3155539e-02 9.3655229e-01]]
# Test image 417: Predicted class 2, Probabilities: [[0.0020355  0.00396195 0.9940025 ]]
# Test image 418: Predicted class 2, Probabilities: [[2.1735199e-04 9.8634441e-04 9.9879622e-01]]
# Test image 419: Predicted class 2, Probabilities: [[4.1366077e-04 1.8504553e-04 9.9940133e-01]]
# Test image 420: Predicted class 2, Probabilities: [[4.7544329e-04 4.7458100e-04 9.9904996e-01]]
# Test image 421: Predicted class 2, Probabilities: [[0.00110756 0.00126665 0.99762577]]
# Test image 422: Predicted class 2, Probabilities: [[0.00733461 0.00478874 0.98787665]]
# Test image 423: Predicted class 2, Probabilities: [[0.05098533 0.00133178 0.94768286]]
# Test image 424: Predicted class 2, Probabilities: [[0.00352622 0.00104626 0.9954275 ]]
# Test image 425: Predicted class 2, Probabilities: [[8.3075327e-05 1.0209595e-03 9.9889588e-01]]
# Test image 426: Predicted class 2, Probabilities: [[6.8971224e-04 3.7087160e-03 9.9560153e-01]]
# Test image 427: Predicted class 2, Probabilities: [[8.4633153e-04 7.7750901e-04 9.9837613e-01]]
# Test image 428: Predicted class 2, Probabilities: [[0.00593898 0.00448106 0.98958   ]]
# Test image 429: Predicted class 2, Probabilities: [[0.01285495 0.00623412 0.9809109 ]]
# Test image 430: Predicted class 2, Probabilities: [[0.02106227 0.01908329 0.9598545 ]]
# Test image 431: Predicted class 2, Probabilities: [[0.00448831 0.00388062 0.9916311 ]]
# Test image 432: Predicted class 2, Probabilities: [[0.00691314 0.00678931 0.9862976 ]]
# Test image 433: Predicted class 1, Probabilities: [[0.0138032 0.7595079 0.226689 ]]
# Test image 434: Predicted class 2, Probabilities: [[4.0648770e-04 3.3099244e-03 9.9628359e-01]]
# Test image 435: Predicted class 2, Probabilities: [[0.00423858 0.01057989 0.9851815 ]]
# Test image 436: Predicted class 2, Probabilities: [[7.9587282e-04 3.5956732e-03 9.9560851e-01]]
# Test image 437: Predicted class 2, Probabilities: [[5.3336046e-04 2.3644075e-03 9.9710220e-01]]
# Test image 438: Predicted class 2, Probabilities: [[0.00288612 0.00821399 0.9888998 ]]
# Test image 439: Predicted class 2, Probabilities: [[0.00118474 0.00550758 0.9933076 ]]
# Test image 440: Predicted class 2, Probabilities: [[7.8863741e-05 2.2514469e-04 9.9969602e-01]]
# Test image 441: Predicted class 0, Probabilities: [[0.52733666 0.40928644 0.06337687]]
# Test image 442: Predicted class 2, Probabilities: [[0.00652271 0.0739677  0.9195096 ]]
# Test image 443: Predicted class 2, Probabilities: [[0.00574975 0.00689917 0.9873511 ]]
# Test image 444: Predicted class 2, Probabilities: [[0.0047892 0.2992346 0.6959762]]
# Test image 445: Predicted class 2, Probabilities: [[0.00607029 0.01402441 0.9799053 ]]
# Test image 446: Predicted class 2, Probabilities: [[0.00398915 0.40571466 0.59029615]]
# Test image 447: Predicted class 2, Probabilities: [[0.00149121 0.00407502 0.9944338 ]]
# Test image 448: Predicted class 2, Probabilities: [[0.02236664 0.10804871 0.8695846 ]]
# Test image 449: Predicted class 2, Probabilities: [[0.18324414 0.14571455 0.67104137]]
# Test image 450: Predicted class 1, Probabilities: [[0.14991947 0.673601   0.17647958]]
# Test image 451: Predicted class 2, Probabilities: [[5.0817925e-04 1.4615576e-02 9.8487628e-01]]
# Test image 452: Predicted class 2, Probabilities: [[0.00197304 0.0065309  0.9914961 ]]
# Test image 453: Predicted class 2, Probabilities: [[6.843087e-05 5.771997e-04 9.993544e-01]]
# Test image 454: Predicted class 1, Probabilities: [[5.9284605e-03 9.9406439e-01 7.2474541e-06]]
# Test image 455: Predicted class 0, Probabilities: [[8.89875889e-01 1.10114165e-01 9.93257072e-06]]
# Test image 456: Predicted class 1, Probabilities: [[3.4660063e-04 9.9960226e-01 5.1120260e-05]]
# Test image 457: Predicted class 0, Probabilities: [[0.6665649  0.33179238 0.00164269]]
# Test image 458: Predicted class 1, Probabilities: [[5.7115545e-04 9.9926656e-01 1.6223345e-04]]
# Test image 459: Predicted class 1, Probabilities: [[1.5691625e-03 9.9842972e-01 1.0701804e-06]]
# Test image 460: Predicted class 1, Probabilities: [[3.577457e-05 9.999641e-01 1.300213e-07]]
# Test image 461: Predicted class 1, Probabilities: [[2.4665242e-01 7.5318027e-01 1.6723966e-04]]
# Test image 462: Predicted class 0, Probabilities: [[0.8875743  0.03218155 0.08024408]]
# Test image 463: Predicted class 0, Probabilities: [[9.6465290e-01 3.5122905e-02 2.2419525e-04]]
# Test image 464: Predicted class 1, Probabilities: [[0.03736339 0.95675164 0.005885  ]]
# Test image 465: Predicted class 1, Probabilities: [[0.01214096 0.95257306 0.03528608]]
# Test image 466: Predicted class 0, Probabilities: [[9.9900144e-01 6.0894917e-04 3.8971592e-04]]
# Test image 467: Predicted class 0, Probabilities: [[0.815922   0.11795171 0.06612625]]
# Test image 468: Predicted class 0, Probabilities: [[0.9823683  0.00134959 0.01628217]]
# Test image 469: Predicted class 0, Probabilities: [[0.9879489  0.0071727  0.00487841]]
# Test image 470: Predicted class 2, Probabilities: [[3.1668227e-04 6.8426540e-04 9.9899906e-01]]
# Test image 471: Predicted class 2, Probabilities: [[0.00859853 0.00874942 0.98265207]]
# Test image 472: Predicted class 1, Probabilities: [[0.00618753 0.92742693 0.06638557]]
# Test image 473: Predicted class 2, Probabilities: [[0.02477239 0.40814877 0.5670788 ]]
# Test image 474: Predicted class 2, Probabilities: [[6.7764142e-04 4.1687349e-03 9.9515367e-01]]
# Test image 475: Predicted class 2, Probabilities: [[0.03146964 0.30281404 0.66571635]]
# Test image 476: Predicted class 2, Probabilities: [[8.9871557e-04 3.3270337e-03 9.9577421e-01]]
# Test image 477: Predicted class 2, Probabilities: [[9.8692044e-04 6.0989900e-04 9.9840313e-01]]
# Test image 478: Predicted class 1, Probabilities: [[0.00380527 0.974295   0.02189974]]
# Test image 479: Predicted class 2, Probabilities: [[0.00304484 0.01774279 0.9792124 ]]
# Test image 480: Predicted class 2, Probabilities: [[8.2761369e-04 4.8531257e-03 9.9431926e-01]]
# Test image 481: Predicted class 2, Probabilities: [[7.1205091e-06 8.5071928e-04 9.9914217e-01]]
# Test image 482: Predicted class 2, Probabilities: [[3.8976339e-04 7.9275537e-03 9.9168265e-01]]
# Test image 483: Predicted class 2, Probabilities: [[5.8053771e-04 4.6136646e-04 9.9895811e-01]]
# Test image 484: Predicted class 2, Probabilities: [[7.3059258e-05 2.9257196e-03 9.9700123e-01]]
# Test image 485: Predicted class 2, Probabilities: [[1.5355618e-04 7.2363140e-03 9.9261016e-01]]
# Test image 486: Predicted class 1, Probabilities: [[0.05595889 0.94159186 0.00244919]]
# Test image 487: Predicted class 1, Probabilities: [[0.4150569  0.5475765  0.03736656]]
# Test image 488: Predicted class 2, Probabilities: [[0.00147788 0.02392602 0.97459614]]
# Test image 489: Predicted class 1, Probabilities: [[0.08015774 0.5838828  0.33595952]]
# Test image 490: Predicted class 0, Probabilities: [[9.9996185e-01 3.6195081e-05 1.9072877e-06]]
# Test image 491: Predicted class 0, Probabilities: [[9.9759018e-01 2.4022530e-03 7.6562355e-06]]
# Test image 492: Predicted class 0, Probabilities: [[9.7881091e-01 2.1147396e-02 4.1812204e-05]]
# Test image 493: Predicted class 0, Probabilities: [[0.5922488  0.40708983 0.00066142]]
# Test image 494: Predicted class 0, Probabilities: [[0.98119444 0.0034358  0.01536975]]
# Test image 495: Predicted class 0, Probabilities: [[9.9976224e-01 4.3101049e-05 1.9463021e-04]]
# Test image 496: Predicted class 1, Probabilities: [[0.49527377 0.5000308  0.00469545]]
# Test image 497: Predicted class 0, Probabilities: [[9.5687443e-01 4.3000285e-02 1.2528828e-04]]
# Test image 498: Predicted class 0, Probabilities: [[0.9740753  0.02337982 0.00254484]]
# Test image 499: Predicted class 0, Probabilities: [[9.8341906e-01 1.6285021e-02 2.9584148e-04]]
# Test image 500: Predicted class 0, Probabilities: [[0.956604   0.04194609 0.00144981]]
# Test image 501: Predicted class 1, Probabilities: [[0.06252431 0.9261514  0.01132432]]
# Test image 502: Predicted class 0, Probabilities: [[9.4232923e-01 5.7640161e-02 3.0654453e-05]]
# Test image 503: Predicted class 0, Probabilities: [[9.8148674e-01 1.8205035e-02 3.0825011e-04]]
# Test image 504: Predicted class 0, Probabilities: [[7.7398920e-01 2.2585332e-01 1.5748487e-04]]
# Test image 505: Predicted class 0, Probabilities: [[9.8441619e-01 1.5247894e-02 3.3597057e-04]]
# Test image 506: Predicted class 0, Probabilities: [[9.9670666e-01 3.2491263e-03 4.4143129e-05]]
# Test image 507: Predicted class 0, Probabilities: [[9.1554344e-01 8.4446989e-02 9.6207004e-06]]
# Test image 508: Predicted class 0, Probabilities: [[9.9999213e-01 7.7452487e-06 1.2295565e-07]]
# Test image 509: Predicted class 1, Probabilities: [[2.3915712e-03 9.9760532e-01 3.1052600e-06]]
# Test image 510: Predicted class 1, Probabilities: [[0.06282283 0.9354842  0.00169313]]
# Test image 511: Predicted class 0, Probabilities: [[9.9875927e-01 1.2132975e-03 2.7403687e-05]]
# Test image 512: Predicted class 1, Probabilities: [[1.2862417e-01 8.7137401e-01 1.7267440e-06]]
# Test image 513: Predicted class 0, Probabilities: [[0.9892252  0.00786145 0.00291334]]
# Test image 514: Predicted class 0, Probabilities: [[0.97407246 0.02301223 0.00291523]]
# Test image 515: Predicted class 0, Probabilities: [[9.9617779e-01 3.7664364e-03 5.5820208e-05]]
# ...
# Test image 9487: Predicted class 1, Probabilities: [[1.8655588e-07 9.9999857e-01 1.2485361e-06]]
# Test image 9488: Predicted class 0, Probabilities: [[9.8949426e-01 1.0500985e-02 4.7453609e-06]]
# Test image 9489: Predicted class 1, Probabilities: [[1.2686512e-02 9.8730844e-01 5.0358412e-06]]
# Test image 9490: Predicted class 0, Probabilities: [[8.7464005e-01 1.2531498e-01 4.4916549e-05]]
# Test image 9491: Predicted class 0, Probabilities: [[9.9010754e-01 9.6204588e-03 2.7189980e-04]]
# Test image 9492: Predicted class 0, Probabilities: [[9.951002e-01 4.885987e-03 1.388753e-05]]
# Test image 9493: Predicted class 1, Probabilities: [[0.00102046 0.9941825  0.0047971 ]]
# Test image 9494: Predicted class 1, Probabilities: [[3.1247106e-04 9.9947900e-01 2.0851500e-04]]
# Test image 9495: Predicted class 1, Probabilities: [[3.1023065e-04 9.9950337e-01 1.8633349e-04]]
# Test image 9496: Predicted class 1, Probabilities: [[0.00369879 0.99476177 0.00153944]]
# Test image 9497: Predicted class 1, Probabilities: [[2.4833708e-04 9.9928159e-01 4.7001318e-04]]
# Test image 9498: Predicted class 1, Probabilities: [[1.08907225e-04 9.99879956e-01 1.11367090e-05]]
# Test image 9499: Predicted class 1, Probabilities: [[4.0254949e-04 9.9953592e-01 6.1600644e-05]]
# Test image 9500: Predicted class 1, Probabilities: [[6.1373757e-03 9.9351752e-01 3.4514870e-04]]
# Test image 9501: Predicted class 1, Probabilities: [[9.5803384e-04 9.9902236e-01 1.9599856e-05]]
# Test image 9502: Predicted class 1, Probabilities: [[1.9700186e-04 9.9884653e-01 9.5650012e-04]]
# Test image 9503: Predicted class 0, Probabilities: [[9.9631906e-01 3.6508450e-03 3.0008927e-05]]
# Test image 9504: Predicted class 0, Probabilities: [[9.9713159e-01 2.6745501e-03 1.9386316e-04]]
# Test image 9505: Predicted class 0, Probabilities: [[9.9134225e-01 8.6360099e-03 2.1743943e-05]]
# Test image 9506: Predicted class 0, Probabilities: [[9.9885678e-01 7.9281459e-04 3.5040785e-04]]
# Test image 9507: Predicted class 0, Probabilities: [[0.8049154  0.19061111 0.00447348]]
# Test image 9508: Predicted class 0, Probabilities: [[9.8695564e-01 1.2390423e-02 6.5387529e-04]]
# Test image 9509: Predicted class 1, Probabilities: [[0.00282885 0.9909321  0.00623906]]
# Test image 9510: Predicted class 1, Probabilities: [[8.2847714e-07 9.9999893e-01 1.8924348e-07]]
# Test image 9511: Predicted class 1, Probabilities: [[1.8892082e-06 9.9999809e-01 3.3532952e-08]]
# Test image 9512: Predicted class 1, Probabilities: [[1.4327414e-06 9.9999845e-01 9.2093984e-08]]
# Test image 9513: Predicted class 1, Probabilities: [[6.1106716e-06 9.9999356e-01 3.6406612e-07]]
# Test image 9514: Predicted class 1, Probabilities: [[3.6014255e-05 9.9996305e-01 9.9709553e-07]]
# Test image 9515: Predicted class 1, Probabilities: [[2.2915136e-05 9.9986458e-01 1.1248256e-04]]
# Test image 9516: Predicted class 1, Probabilities: [[3.124708e-05 9.998952e-01 7.354015e-05]]
# Test image 9517: Predicted class 2, Probabilities: [[8.470643e-04 5.415695e-03 9.937372e-01]]
# Test image 9518: Predicted class 2, Probabilities: [[9.1169163e-04 6.2862225e-04 9.9845970e-01]]
# Test image 9519: Predicted class 2, Probabilities: [[0.02245064 0.00110866 0.9764407 ]]
# Test image 9520: Predicted class 2, Probabilities: [[3.1124757e-04 2.6587248e-04 9.9942291e-01]]
# Test image 9521: Predicted class 2, Probabilities: [[0.0167809  0.01993004 0.963289  ]]
# Test image 9522: Predicted class 2, Probabilities: [[4.0178180e-05 1.4848266e-04 9.9981135e-01]]
# Test image 9523: Predicted class 2, Probabilities: [[8.2127820e-04 1.8152948e-02 9.8102576e-01]]
# Test image 9524: Predicted class 2, Probabilities: [[1.6074481e-04 7.9959945e-04 9.9903959e-01]]
# Test image 9525: Predicted class 2, Probabilities: [[1.6593267e-05 9.2433821e-03 9.9074006e-01]]
# Test image 9526: Predicted class 2, Probabilities: [[3.6780217e-05 4.0388713e-04 9.9955934e-01]]
# Test image 9527: Predicted class 2, Probabilities: [[3.1423493e-05 1.1129259e-03 9.9885571e-01]]
# Test image 9528: Predicted class 2, Probabilities: [[0.00252972 0.01254428 0.98492604]]
# Test image 9529: Predicted class 2, Probabilities: [[7.74017011e-04 1.34223495e-02 9.85803604e-01]]
# Test image 9530: Predicted class 2, Probabilities: [[2.5300210e-04 1.6684451e-03 9.9807858e-01]]
# Test image 9531: Predicted class 2, Probabilities: [[0.00121175 0.00186489 0.9969234 ]]
# Test image 9532: Predicted class 2, Probabilities: [[1.7054877e-04 1.2200079e-02 9.8762941e-01]]
# Test image 9533: Predicted class 2, Probabilities: [[0.00622331 0.08211169 0.911665  ]]
# Test image 9534: Predicted class 2, Probabilities: [[7.5611565e-04 6.8988197e-04 9.9855405e-01]]
# Test image 9535: Predicted class 2, Probabilities: [[0.00352404 0.06822766 0.92824835]]
# Test image 9536: Predicted class 2, Probabilities: [[1.7480069e-04 2.5975909e-03 9.9722761e-01]]
# Test image 9537: Predicted class 1, Probabilities: [[3.4085172e-04 9.9829119e-01 1.3679659e-03]]
# Test image 9538: Predicted class 1, Probabilities: [[0.03509833 0.9630297  0.00187196]]
# Test image 9539: Predicted class 1, Probabilities: [[6.868306e-04 9.893607e-01 9.952435e-03]]
# Test image 9540: Predicted class 1, Probabilities: [[5.8751157e-04 9.9792284e-01 1.4896455e-03]]
# Test image 9541: Predicted class 1, Probabilities: [[9.9727607e-05 9.9988174e-01 1.8503079e-05]]
# Test image 9542: Predicted class 1, Probabilities: [[8.6837367e-04 9.9825889e-01 8.7275688e-04]]
# Test image 9543: Predicted class 1, Probabilities: [[0.00190745 0.9951137  0.00297897]]
# Test image 9544: Predicted class 0, Probabilities: [[7.79497683e-01 2.20488161e-01 1.41639675e-05]]
# Test image 9545: Predicted class 1, Probabilities: [[0.14156877 0.83937997 0.01905127]]
# Test image 9546: Predicted class 2, Probabilities: [[1.3692653e-02 5.0392107e-04 9.8580337e-01]]
# Test image 9547: Predicted class 2, Probabilities: [[2.3582925e-04 8.5316773e-05 9.9967885e-01]]
# Test image 9548: Predicted class 2, Probabilities: [[2.9466860e-04 1.5869747e-04 9.9954659e-01]]
# Test image 9549: Predicted class 2, Probabilities: [[1.3039391e-03 5.1974488e-04 9.9817634e-01]]
# Test image 9550: Predicted class 2, Probabilities: [[1.3091248e-04 1.4060296e-04 9.9972850e-01]]
# Test image 9551: Predicted class 2, Probabilities: [[0.00243543 0.00145417 0.9961104 ]]
# Test image 9552: Predicted class 2, Probabilities: [[0.00106864 0.00246858 0.99646276]]
# Test image 9553: Predicted class 2, Probabilities: [[0.00189759 0.00560114 0.9925013 ]]
# Test image 9554: Predicted class 2, Probabilities: [[1.9967231e-04 6.7902054e-04 9.9912137e-01]]
# Test image 9555: Predicted class 2, Probabilities: [[7.5756347e-05 3.1830055e-05 9.9989235e-01]]
# Test image 9556: Predicted class 2, Probabilities: [[1.3055486e-04 1.3453660e-04 9.9973494e-01]]
# Test image 9557: Predicted class 2, Probabilities: [[3.1123497e-04 9.3798888e-05 9.9959499e-01]]
# Test image 9558: Predicted class 2, Probabilities: [[2.52172118e-04 1.07616615e-04 9.99640226e-01]]
# Test image 9559: Predicted class 2, Probabilities: [[1.2074676e-05 2.4394611e-05 9.9996352e-01]]
# Test image 9560: Predicted class 2, Probabilities: [[0.00583108 0.00147175 0.9926972 ]]
# Test image 9561: Predicted class 2, Probabilities: [[4.381740e-05 7.171432e-05 9.998845e-01]]
# Test image 9562: Predicted class 2, Probabilities: [[3.5742330e-04 1.6658004e-04 9.9947602e-01]]
# Test image 9563: Predicted class 2, Probabilities: [[0.02616282 0.00818942 0.96564776]]
# Test image 9564: Predicted class 2, Probabilities: [[4.5142940e-04 1.3100648e-04 9.9941754e-01]]
# Test image 9565: Predicted class 2, Probabilities: [[0.00636169 0.00395013 0.9896882 ]]
# Test image 9566: Predicted class 1, Probabilities: [[0.01600598 0.9823699  0.00162407]]
# Test image 9567: Predicted class 0, Probabilities: [[0.7541317  0.20291124 0.04295704]]
# Test image 9568: Predicted class 0, Probabilities: [[0.9865565  0.00643741 0.00700601]]
# Test image 9569: Predicted class 0, Probabilities: [[9.9891233e-01 8.9499826e-04 1.9266403e-04]]
# Test image 9570: Predicted class 0, Probabilities: [[9.8179173e-01 1.7598031e-02 6.1028858e-04]]
# Test image 9571: Predicted class 0, Probabilities: [[9.9833268e-01 1.3776253e-03 2.8964676e-04]]
# Test image 9572: Predicted class 0, Probabilities: [[9.9237776e-01 7.2628208e-03 3.5940748e-04]]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[19], line 9
#       6 true_labels = []
#       7 predicted_labels = []
# ----> 9 for images, labels in test_loader:
#      10     images = images.to(device)
#      11     true_labels.extend(labels.numpy())
#
# File c:\Users\HP1\Desktop\Spiced\capstone-project\.venv\Lib\site-packages\torch\utils\data\dataloader.py:701, in _BaseDataLoaderIter.__next__(self)
#     698 if self._sampler_iter is None:
#     699     # TODO(https://github.com/pytorch/pytorch/issues/76750)
#     700     self._reset()  # type: ignore[call-arg]
# --> 701 data = self._next_data()
#     702 self._num_yielded += 1
#     703 if (
#     704     self._dataset_kind == _DatasetKind.Iterable
#     705     and self._IterableDataset_len_called is not None
#     706     and self._num_yielded > self._IterableDataset_len_called
#     707 ):
#
# File c:\Users\HP1\Desktop\Spiced\capstone-project\.venv\Lib\site-packages\torch\utils\data\dataloader.py:757, in _SingleProcessDataLoaderIter._next_data(self)
#     755 def _next_data(self):
#     756     index = self._next_index()  # may raise StopIteration
# --> 757     data = self._dataset_fetcher.fetch(index)  # may raise StopIteration
#     758     if self._pin_memory:
#     759         data = _utils.pin_memory.pin_memory(data, self._pin_memory_device)
#
# File c:\Users\HP1\Desktop\Spiced\capstone-project\.venv\Lib\site-packages\torch\utils\data\_utils\fetch.py:52, in _MapDatasetFetcher.fetch(self, possibly_batched_index)
#      50         data = self.dataset.__getitems__(possibly_batched_index)
#      51     else:
# ---> 52         data = [self.dataset[idx] for idx in possibly_batched_index]
#      53 else:
#      54     data = self.dataset[possibly_batched_index]
#
# File c:\Users\HP1\Desktop\Spiced\capstone-project\.venv\Lib\site-packages\torch\utils\data\_utils\fetch.py:52, in <listcomp>(.0)
#      50         data = self.dataset.__getitems__(possibly_batched_index)
#      51     else:
# ---> 52         data = [self.dataset[idx] for idx in possibly_batched_index]
#      53 else:
#      54     data = self.dataset[possibly_batched_index]
#
# Cell In[16], line 43, in MRIDataset.__getitem__(self, index)
#      41 label = row['severity']
#      42 dicom_image = pydicom.dcmread(image_path)
# ---> 43 image = dicom_image.pixel_array.astype(float)
#      44 image = (image / image.max() * 255).astype('uint8')
#      45 if len(image.shape) == 2:  # Grayscale
#
# File c:\Users\HP1\Desktop\Spiced\capstone-project\.venv\Lib\site-packages\pydicom\dataset.py:2193, in Dataset.pixel_array(self)
#    2133 @property
#    2134 def pixel_array(self) -> "numpy.ndarray":
#    2135     """Return the pixel data as a :class:`numpy.ndarray`.
#    2136
#    2137     .. warning::
#    (...)
#    2191         that iterates through the image frames.
#    2192     """
# -> 2193     self.convert_pixel_data()
#    2194     return cast("numpy.ndarray", self._pixel_array)
#
# File c:\Users\HP1\Desktop\Spiced\capstone-project\.venv\Lib\site-packages\pydicom\dataset.py:1726, in Dataset.convert_pixel_data(self, handler_name)
#    1723 if not opts["use_pdh"]:
#    1724     # Use 'pydicom.pixels' backend
#    1725     opts["decoding_plugin"] = name
# -> 1726     self._pixel_array = pixel_array(self, **opts)
#    1727     self._pixel_id = get_image_pixel_ids(self)
#    1728 else:
#    1729     # Use 'pydicom.pixel_data_handlers' backend
#
# File c:\Users\HP1\Desktop\Spiced\capstone-project\.venv\Lib\site-packages\pydicom\pixels\utils.py:1430, in pixel_array(src, ds_out, specific_tags, index, raw, decoding_plugin, **kwargs)
#    1424         raise NotImplementedError(
#    1425             "Unable to decode the pixel data as a (0002,0010) 'Transfer Syntax "
#    1426             f"UID' value of '{tsyntax.name}' is not supported"
#    1427         )
#    1429     opts = as_pixel_options(ds, **kwargs)
# -> 1430     return decoder.as_array(
#    1431         ds,
#    1432         index=index,
#    1433         validate=True,
#    1434         raw=raw,
#    1435         decoding_plugin=decoding_plugin,
#    1436         **opts,
#    1437     )[0]
#    1439 f: BinaryIO
#    1440 if not hasattr(src, "read"):
#
# File c:\Users\HP1\Desktop\Spiced\capstone-project\.venv\Lib\site-packages\pydicom\pixels\decoders\base.py:1000, in Decoder.as_array(self, src, index, validate, raw, decoding_plugin, **kwargs)
#     997     as_writeable = True
#     999 as_frame = index is not None
# -> 1000 arr = runner.reshape(func(runner, index), as_frame=as_frame)
#    1002 if runner._test_for("sign_correction"):
#    1003     arr = _apply_sign_correction(arr, runner)
#
# File c:\Users\HP1\Desktop\Spiced\capstone-project\.venv\Lib\site-packages\pydicom\pixels\decoders\base.py:1067, in Decoder._as_array_encapsulated(runner, index)
#    1065 frame_generator = runner.iter_decode()
#    1066 for idx in range(runner.number_of_frames):
# -> 1067     frame = next(frame_generator)
#    1068     start = idx * pixels_per_frame
#    1069     arr[start : start + pixels_per_frame] = np.frombuffer(
#    1070         frame, dtype=runner.pixel_dtype
#    1071     )
#
# File c:\Users\HP1\Desktop\Spiced\capstone-project\.venv\Lib\site-packages\pydicom\pixels\decoders\base.py:458, in DecodeRunner.iter_decode(self)
#     452             LOGGER.warning(
#     453                 f"The decoding plugin '{name}' failed to decode the "
#     454                 f"frame at index {index}"
#     455             )
#     457     # Otherwise try all decoders
# --> 458     yield self._decode_frame(src)
#     460 if self.is_binary:
#     461     cast(BinaryIO, self.src).seek(file_offset)
#
# File c:\Users\HP1\Desktop\Spiced\capstone-project\.venv\Lib\site-packages\pydicom\pixels\decoders\base.py:355, in DecodeRunner._decode_frame(self, src)
#     352 for name, func in self._decoders.items():
#     353     try:
#     354         # Attempt to decode the frame
# --> 355         frame = func(src, self)
#     357         # Decode success, if we were previously successful then
#     358         #   warn about the change to the new decoder
#     359         if hasattr(self, "_previous") and self._previous[1] != func:
#
# File c:\Users\HP1\Desktop\Spiced\capstone-project\.venv\Lib\site-packages\pydicom\pixels\decoders\rle.py:51, in _decode_frame(src, runner)
#      24 def _decode_frame(src: bytes, runner: DecodeRunner) -> bytearray:
#      25     """Wrapper for use with the decoder interface.
#      26
#      27     Parameters
#    (...)
#      49         The decoded frame, ordered as planar configuration 1.
#      50     """
# ---> 51     frame = _rle_decode_frame(
#      52         src,
#      53         runner.rows,
#      54         runner.columns,
#      55         runner.samples_per_pixel,
#      56         runner.bits_allocated,
#      57         runner.get_option("rle_segment_order", ">"),
#      58     )
#      59     # Update the runner options to ensure the reshaping is correct
#      60     # Only do this if we successfully decoded the frame
#      61     runner.set_option("planar_configuration", 1)
#
# File c:\Users\HP1\Desktop\Spiced\capstone-project\.venv\Lib\site-packages\pydicom\pixels\decoders\rle.py:149, in _rle_decode_frame(src, rows, columns, nr_samples, nr_bits, segment_order)
#     146 ii = sample_number * bytes_per_sample + byte_offset
#     147 # ii is 1, 0, 3, 2, 5, 4 for the example above
#     148 # This is where the segment order correction occurs
# --> 149 segment = _rle_decode_segment(src[offsets[ii] : offsets[ii + 1]])
#     151 # Check that the number of decoded bytes is correct
#     152 actual_length = len(segment)
#
# File c:\Users\HP1\Desktop\Spiced\capstone-project\.venv\Lib\site-packages\pydicom\pixels\decoders\rle.py:195, in _rle_decode_segment(src)
#     192 result_extend = result.extend
#     194 try:
# --> 195     while True:
#     196         # header_byte is N + 1
#     197         header_byte = src[pos] + 1
#     198         pos += 1
#
# KeyboardInterrupt:

# %%
# Convert the list of probabilities to a numpy array for easier manipulation
probabilities_array = np.vstack(probabilities_list)

# Ensure the length of probabilities_array matches the length of test_df
probabilities_array = probabilities_array[:len(test_df)]

# Add the probabilities to the test_df DataFrame
test_df['Probability_Class_0'] = probabilities_array[:, 0]
test_df['Probability_Class_1'] = probabilities_array[:, 1]
test_df['Probability_Class_2'] = probabilities_array[:, 2]

# Round the probabilities to 4 decimal places
test_df['Probability_Class_0'] = test_df['Probability_Class_0'].round(4)
test_df['Probability_Class_1'] = test_df['Probability_Class_1'].round(4)
test_df['Probability_Class_2'] = test_df['Probability_Class_2'].round(4)
# Add the predicted classes to the test_df DataFrame
test_df['Predicted_Class'] = results



# Display the updated DataFrame
 
test_df.head()
# Out:
#    study_id  severity  condition  level     series_id           x           y                                         image_path  missing_image  Probability_Class_0  Probability_Class_1  Probability_Class_2  Predicted_Class
# 0   4003253         0          0  l5/s1  1.054714e+09  197.100569  289.457306   data/train_images_origin/4003253/702807833/3.dcm          False               0.9962               0.0038               0.0000                0
# 1   4646740         1          0  l5/s1  3.486248e+09  235.980844  360.313610  data/train_images_origin/4646740/3486248476/2.dcm          False               0.0000               1.0000               0.0000                1
# 2   4646740         1          0  l5/s1  3.486248e+09  235.980844  360.313610  data/train_images_origin/4646740/3666319702/16...          False               0.0062               0.9917               0.0022                1
# 3   4646740         1          0  l5/s1  3.486248e+09  235.980844  360.313610  data/train_images_origin/4646740/3486248476/16...          False               0.0000               0.9999               0.0001                1
# 4   4646740         1          0  l5/s1  3.486248e+09  235.980844  360.313610  data/train_images_origin/4646740/3666319702/10...          False               0.0006               0.9994               0.0000                1

# %%
# Group by severity and sum the Probability_Class_1
severity_prob_sum_all_classes = test_df.groupby('severity')[['Probability_Class_0', 'Probability_Class_1', 'Probability_Class_2']].mean()

# Print the result
severity_prob_sum_all_classes
# Use severity_prob_sum_all_classes as confusion matrix
conf_matrix_prob_df = severity_prob_sum_all_classes 
# Create a confusion matrix from severity and predicted class
conf_matrix_severity_pred = confusion_matrix(test_df['severity'], test_df['Predicted_Class'])

# Create a DataFrame from the confusion matrix
conf_matrix_severity_pred_df = pd.DataFrame(
    conf_matrix_severity_pred, 
    index=[f"Actual {i}" for i in range(len(conf_matrix_severity_pred))], 
    columns=[f"Predicted {i}" for i in range(len(conf_matrix_severity_pred[0]))]
)

# Print the confusion matrix DataFrame
print(conf_matrix_severity_pred_df)

# Optionally, display it using a more formatted view (e.g., in Jupyter Notebook)
conf_matrix_severity_pred_df.style.background_gradient(cmap='Blues')
# Print the confusion matrix DataFrame
print(conf_matrix_prob_df)

# Optionally, display it using a more formatted view (e.g., in Jupyter Notebook)
conf_matrix_prob_df.style.background_gradient(cmap='Blues')
# Out:
#           Predicted 0  Predicted 1  Predicted 2
# Actual 0         2705          386           31
# Actual 1           84         3191           31
# Actual 2           35          173         2937
#           Probability_Class_0  Probability_Class_1  Probability_Class_2
# severity
# 0                    0.844914             0.143171             0.011912
# 1                    0.031295             0.957033             0.011667
# 2                    0.020081             0.069996             0.909923
# <style type="text/css">
# #T_a4a75_row0_col0, #T_a4a75_row1_col1, #T_a4a75_row2_col2 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_a4a75_row0_col1 {
#   background-color: #e7f0fa;
#   color: #000000;
# }
# #T_a4a75_row0_col2, #T_a4a75_row1_col2, #T_a4a75_row2_col0, #T_a4a75_row2_col1 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_a4a75_row1_col0 {
#   background-color: #f5f9fe;
#   color: #000000;
# }
# </style>
# <table id="T_a4a75">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_a4a75_level0_col0" class="col_heading level0 col0" >Probability_Class_0</th>
#       <th id="T_a4a75_level0_col1" class="col_heading level0 col1" >Probability_Class_1</th>
#       <th id="T_a4a75_level0_col2" class="col_heading level0 col2" >Probability_Class_2</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >severity</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a4a75_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_a4a75_row0_col0" class="data row0 col0" >0.844914</td>
#       <td id="T_a4a75_row0_col1" class="data row0 col1" >0.143171</td>
#       <td id="T_a4a75_row0_col2" class="data row0 col2" >0.011912</td>
#     </tr>
#     <tr>
#       <th id="T_a4a75_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_a4a75_row1_col0" class="data row1 col0" >0.031295</td>
#       <td id="T_a4a75_row1_col1" class="data row1 col1" >0.957033</td>
#       <td id="T_a4a75_row1_col2" class="data row1 col2" >0.011667</td>
#     </tr>
#     <tr>
#       <th id="T_a4a75_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_a4a75_row2_col0" class="data row2 col0" >0.020081</td>
#       <td id="T_a4a75_row2_col1" class="data row2 col1" >0.069996</td>
#       <td id="T_a4a75_row2_col2" class="data row2 col2" >0.909923</td>
#     </tr>
#   </tbody>
# </table>

# %%
conf_matrix_severity_pred_df.style.background_gradient(cmap='Blues')

# %%
from sklearn.metrics import confusion_matrix
import pandas as pd
import numpy as np

# Ensure true_labels and predicted_labels have the same length
min_length = min(len(true_labels), len(predicted_labels))
true_labels = true_labels[:min_length]
predicted_labels = predicted_labels[:min_length]

# Generate the confusion matrix
conf_matrix = confusion_matrix(true_labels, predicted_labels)

# Create a DataFrame from the confusion matrix
conf_matrix_df = pd.DataFrame(
    conf_matrix, 
    index=[f"Actual {i}" for i in range(len(conf_matrix))], 
    columns=[f"Predicted {i}" for i in range(len(conf_matrix[0]))]
)

# Print the confusion matrix DataFrame
print(conf_matrix_df)

# Optionally, display it using a more formatted view (e.g., in Jupyter Notebook)
conf_matrix_df.style.background_gradient(cmap='Blues')

# %%
from sklearn.metrics import precision_score, recall_score, accuracy_score
# Calculate precision, recall, and accuracy using mean_probabilities_df
precision = precision_score(true_labels, predicted_labels, average='weighted')
recall = recall_score(true_labels, predicted_labels, average='weighted')
accuracy = accuracy_score(true_labels, predicted_labels)

print(f"Precision: {precision:.4f}")
print(f"Recall: {recall:.4f}")
print(f"Accuracy: {accuracy:.4f}")
# Out:
# Precision: 0.8903
# Recall: 0.8788
# Accuracy: 0.8788
